# %%
# import the necessary packages
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
import requests
import io
import glob

# %%
# Set max number of rows and and columns to view in one go
pd.set_option('max_columns', 40)
pd.set_option('max_rows', 100)

# %%
# Set up the database connection wiht Psycopg2
db = psycopg2.connect(dbname='r7', user='postgres')
cursor=db.cursor()

# Set up a database connection using sqlalchemy
engine = create_engine('postgres://postgres:postgres@localhost:5432/r7')

# %%
# Define variables

# Define the input and output strings
input_string = '../_4_data_extracts/matchwithtimeline_file_xlms/'
output_strig = '../_6_data_clean/'

# Define schemas
schema1 = '_0_original_data'
schema2 = '_1_data_views'

# %%
# Read the matchDetailwithtimeline files into one variable
files = glob.glob(input_string + "**/*.xml", recursive=True)
files
# Out:
# ['../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1692_24806.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1692_24812.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1618_23463.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1612_22901.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1612_22915.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1612_22929.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1686_24225.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1693_24939.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1619_23548.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1693_24911.xml',
#  '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1686_24219.xml',
# ...

# %%
file = '../_4_data_extracts/matchwithtimeline_file_xlms/matchwithtimeline_1692_24806.xml'

# %%
pd.read_sql_query(";with x as (select xmlparse as t1 from XMLPARSE(DOCUMENT convert_from(pg_read_binary_file('"+file+"'), 'UTF8'))) \
SELECT \
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:MatchID/text()',t1,ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as MatchID,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:KickOff/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as KickOff,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:GMTDifference/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as GMTDifference,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team1ID/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team1ID,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team1Name/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team1Name,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team1Score/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team1Score,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team2ID/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team2ID,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team2Name/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team2Name,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team2Score/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team2Score,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Stadium/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Stadium,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:City/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as City,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Attendance/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Attendance,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Stage/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Stage,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:GroupID/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as GroupID,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Status/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Status,\
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:MatchNumber/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as MatchNumber\
--into MatchDetailWithTimeline\
from x",db)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1403             else:
# -> 1404                 cur.execute(*args)
#    1405             return cur
#
# ProgrammingError: column "t1" does not exist
# LINE 1: ...thTimeline/x1:MatchInformation/x1:MatchID/text()',t1,ARRAY[A...
#                                                              ^
#
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-13-0ab78dfb73a5> in <module>()
# ...

# %%
;with x as (select xmlparse as t1 from XMLPARSE(DOCUMENT convert_from(pg_read_binary_file('C:/Program Files/PostgreSQL/10/data/matchwithtimeline_1611_22808.xml'), 'UTF8')))
SELECT
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:MatchID/text()',t1,ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as MatchID,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:KickOff/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as KickOff,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:GMTDifference/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as GMTDifference,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team1ID/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team1ID,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team1Name/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team1Name,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team1Score/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team1Score,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team2ID/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team2ID,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team2Name/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team2Name,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Team2Score/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Team2Score,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Stadium/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Stadium,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:City/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as City,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Attendance/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Attendance,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Stage/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Stage,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:GroupID/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as GroupID,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:Status/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as Status,
unnest(xpath('/x1:MatchDetailWithTimeline/x1:MatchInformation/x1:MatchNumber/text()',t1, ARRAY[ARRAY['x1','http://webservices.irb.com/']])) as MatchNumber
--into MatchDetailWithTimeline
from x
