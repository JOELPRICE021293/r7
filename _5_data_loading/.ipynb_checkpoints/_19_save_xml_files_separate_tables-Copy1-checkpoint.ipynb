# %% [markdown]
# Author: Marijse
#
# Aim: Save all xml files for the following four tables
# - PlayeProfileWithTestBreakdown
# - Playerprofile
# - Match
# - MatchWithTimeline

# %%
# import the necessary packages
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
import glob
from datetime import datetime
import urllib.request
import requests
from requests import get
import io

# %%
# Set up the database connection wiht Psycopg2
db = psycopg2.connect(dbname='r7', user='postgres')
cursor=db.cursor()

# Set up a database connection using sqlalchemy
engine = create_engine('postgres://postgres:postgres@localhost:5432/r7')

# %%
eventid = pd.read_sql_query("select distinct(tournament_id) from _0_original_data.match_fixtures",db)
eventid_list = eventid['tournament_id'].tolist()

# %% [markdown]
# ### Generate match with timeline

# %%
# Loop to go over all the matchwithtimeline xml files and save locally
for k in eventid_list:
    
    print('the tournament id is ' + k)
    
    matchid = pd.read_sql_query("select distinct(matchid) from _0_original_data.match_fixtures where tournament_id = '"+k+"'",db)
    matchid_list = list(matchid.matchid.unique())
    
    for m in matchid_list:
            
        print('the matchid is ' + m)
                            
        url = 'http://webservices.irb.com/EventInformation.asmx/MatchWithTimeline?uid=e9656db8-ffb5-4115-ac0b-cbd5688e6648&eventid='+k+'&matchid='+m
        file_name = 'matchwithtimeline_'+k+'_'+m+'.xml'
        urllib.request.urlretrieve(url, file_name)

# %% [markdown]
# ### Generate match

# %%
# Loop to go over all the match xml files and save locally
for k in ['1688','1689','1690','1619','1620','1684','1615','1616','1617']:
    
    print('the tournament id is ' + k)
    
    # event id 24182 for event 1686 gives an error on the database page, hence we will skip the this event.
    matchid = pd.read_sql_query("select distinct(matchid) from _0_original_data.match_fixtures where tournament_id = '"+k+"' and matchid <> '24182'",db)
    matchid_list = list(matchid.matchid.unique())
    
    for m in matchid_list:
            
        print('the matchid is ' + m)
                            
        url = 'http://webservices.irb.com/EventInformation.asmx/Match?UID=e9656db8-ffb5-4115-ac0b-cbd5688e6648&EventID='+k+'&MatchID='+m
        file_name = 'match_'+k+'_'+m+'.xml'
        urllib.request.urlretrieve(url, file_name)

# %% [markdown]
# ### Generate player profile

# %%
# Loop to go over all the playerprofile xml files and save locally
for k in eventid_list:
    print('the tournament id is ' + k)
    
    personid = pd.read_sql_query("select distinct(personid) from _0_original_data.full_squads_info where tournament_id = '"+k+"'",db)
    personid_list = list(personid.personid.unique())
    
    for m in personid_list:
            
        print('the personid is ' + m)
                            
        url = 'http://webservices.irb.com/EventInformation.asmx/PlayerProfile?uid=e9656db8-ffb5-4115-ac0b-cbd5688e6648&eventid='+k+'&personid='+m
        file_name = 'playerprofile_'+k+'_'+m+'.xml'
        urllib.request.urlretrieve(url, file_name)

# %% [markdown]
# ### Generate player profile with test breakdown

# %%
# Loop to go over all the playerprofile xml files and save locally
for k in ['1686','1687', '1688', '1689', '1690', '1691', '1692', '1693']:
    
    print('the tournament id is ' + k)
    
    personid = pd.read_sql_query("select distinct(personid) from _0_original_data.full_squads_info where tournament_id = '"+k+"'",db)
    personid_list = list(personid.personid.unique())
    
    for m in personid_list:
            
        print('the tournament id is '+ k +' and the personid is ' + m)
                            
        url = 'http://webservices.irb.com/EventInformation.asmx/PlayerProfileWithTestBreakdown?uid=e9656db8-ffb5-4115-ac0b-cbd5688e6648&eventid='+k+'&personid='+m
        file_name = 'playerprofilewithtestbreakdown_'+k+'_'+m+'.xml'
        urllib.request.urlretrieve(url, file_name)
# Out:
# the tournament id is 1686
# the tournament id is 1686 and the personid is 55785
# the tournament id is 1686 and the personid is 54758
# the tournament id is 1686 and the personid is 36561
# the tournament id is 1686 and the personid is 57163
# the tournament id is 1686 and the personid is 59723
# the tournament id is 1686 and the personid is 49046
# the tournament id is 1686 and the personid is 57353
# the tournament id is 1686 and the personid is 53380
# the tournament id is 1686 and the personid is 50538
# the tournament id is 1686 and the personid is 54678
# the tournament id is 1686 and the personid is 55027
# the tournament id is 1686 and the personid is 39694
# the tournament id is 1686 and the personid is 48550
# the tournament id is 1686 and the personid is 59648
# the tournament id is 1686 and the personid is 58720
# the tournament id is 1686 and the personid is 51742
# the tournament id is 1686 and the personid is 32149
# the tournament id is 1686 and the personid is 52675
# the tournament id is 1686 and the personid is 54728
# the tournament id is 1686 and the personid is 29071
# the tournament id is 1686 and the personid is 42461
# the tournament id is 1686 and the personid is 51604
# the tournament id is 1686 and the personid is 59428
# the tournament id is 1686 and the personid is 51362
# the tournament id is 1686 and the personid is 52549
# the tournament id is 1686 and the personid is 43474
# the tournament id is 1686 and the personid is 54246
# the tournament id is 1686 and the personid is 54679
# the tournament id is 1686 and the personid is 57156
# the tournament id is 1686 and the personid is 52436
# the tournament id is 1686 and the personid is 54200
# the tournament id is 1686 and the personid is 59366
# the tournament id is 1686 and the personid is 52851
# the tournament id is 1686 and the personid is 56563
# the tournament id is 1686 and the personid is 42991
# the tournament id is 1686 and the personid is 56552
# the tournament id is 1686 and the personid is 36055
# the tournament id is 1686 and the personid is 51278
# the tournament id is 1686 and the personid is 50593
# the tournament id is 1686 and the personid is 29397
# the tournament id is 1686 and the personid is 43088
# the tournament id is 1686 and the personid is 49529
# the tournament id is 1686 and the personid is 49125
# the tournament id is 1686 and the personid is 48789
# the tournament id is 1686 and the personid is 56571
# the tournament id is 1686 and the personid is 32150
# the tournament id is 1686 and the personid is 39111
# the tournament id is 1686 and the personid is 50766
# the tournament id is 1686 and the personid is 59429
# the tournament id is 1686 and the personid is 59476
# the tournament id is 1686 and the personid is 59655
# the tournament id is 1686 and the personid is 52706
# the tournament id is 1686 and the personid is 47437
# the tournament id is 1686 and the personid is 52800
# the tournament id is 1686 and the personid is 56614
# the tournament id is 1686 and the personid is 49224
# the tournament id is 1686 and the personid is 52277
# the tournament id is 1686 and the personid is 54261
# the tournament id is 1686 and the personid is 48567
# the tournament id is 1686 and the personid is 59639
# the tournament id is 1686 and the personid is 50326
# the tournament id is 1686 and the personid is 56619
# the tournament id is 1686 and the personid is 51118
# the tournament id is 1686 and the personid is 46233
# the tournament id is 1686 and the personid is 48983
# the tournament id is 1686 and the personid is 45510
# the tournament id is 1686 and the personid is 54198
# the tournament id is 1686 and the personid is 59638
# the tournament id is 1686 and the personid is 55780
# the tournament id is 1686 and the personid is 59352
# the tournament id is 1686 and the personid is 47880
# the tournament id is 1686 and the personid is 59640
# the tournament id is 1686 and the personid is 59647
# the tournament id is 1686 and the personid is 44113
# the tournament id is 1686 and the personid is 30554
# the tournament id is 1686 and the personid is 54085
# the tournament id is 1686 and the personid is 51788
# the tournament id is 1686 and the personid is 52241
# the tournament id is 1686 and the personid is 52840
# the tournament id is 1686 and the personid is 51552
# the tournament id is 1686 and the personid is 27056
# the tournament id is 1686 and the personid is 54760
# the tournament id is 1686 and the personid is 55641
# the tournament id is 1686 and the personid is 57702
# the tournament id is 1686 and the personid is 59653
# the tournament id is 1686 and the personid is 38830
# the tournament id is 1686 and the personid is 52266
# the tournament id is 1686 and the personid is 48980
# the tournament id is 1686 and the personid is 50319
# the tournament id is 1686 and the personid is 59644
# the tournament id is 1686 and the personid is 29030
# the tournament id is 1686 and the personid is 54252
# the tournament id is 1686 and the personid is 59649
# the tournament id is 1686 and the personid is 59479
# the tournament id is 1686 and the personid is 59656
# the tournament id is 1686 and the personid is 43174
# the tournament id is 1686 and the personid is 52350
# the tournament id is 1686 and the personid is 57843
# the tournament id is 1686 and the personid is 56577
# the tournament id is 1686 and the personid is 55833
# the tournament id is 1686 and the personid is 59652
# the tournament id is 1686 and the personid is 59645
# the tournament id is 1686 and the personid is 45717
# the tournament id is 1686 and the personid is 51523
# the tournament id is 1686 and the personid is 52181
# the tournament id is 1686 and the personid is 59410
# the tournament id is 1686 and the personid is 52824
# the tournament id is 1686 and the personid is 53267
# the tournament id is 1686 and the personid is 59661
# the tournament id is 1686 and the personid is 54282
# the tournament id is 1686 and the personid is 57295
# the tournament id is 1686 and the personid is 56609
# the tournament id is 1686 and the personid is 45506
# the tournament id is 1686 and the personid is 54959
# the tournament id is 1686 and the personid is 52312
# the tournament id is 1686 and the personid is 56598
# the tournament id is 1686 and the personid is 52291
# the tournament id is 1686 and the personid is 52384
# the tournament id is 1686 and the personid is 59662
# the tournament id is 1686 and the personid is 59424
# the tournament id is 1686 and the personid is 51662
# the tournament id is 1686 and the personid is 45192
# the tournament id is 1686 and the personid is 59354
# the tournament id is 1686 and the personid is 54287
# the tournament id is 1686 and the personid is 39659
# the tournament id is 1686 and the personid is 52625
# the tournament id is 1686 and the personid is 44109
# the tournament id is 1686 and the personid is 56548
# the tournament id is 1686 and the personid is 54989
# the tournament id is 1686 and the personid is 53333
# the tournament id is 1686 and the personid is 59426
# the tournament id is 1686 and the personid is 48582
# the tournament id is 1686 and the personid is 59646
# the tournament id is 1686 and the personid is 56579
# the tournament id is 1686 and the personid is 46475
# the tournament id is 1686 and the personid is 57157
# the tournament id is 1686 and the personid is 33406
# the tournament id is 1686 and the personid is 51080
# the tournament id is 1686 and the personid is 59654
# the tournament id is 1686 and the personid is 48360
# the tournament id is 1686 and the personid is 51099
# the tournament id is 1686 and the personid is 52829
# the tournament id is 1686 and the personid is 52894
# the tournament id is 1686 and the personid is 59403
# the tournament id is 1686 and the personid is 46033
# the tournament id is 1686 and the personid is 53249
# the tournament id is 1686 and the personid is 59433
# the tournament id is 1686 and the personid is 56575
# the tournament id is 1686 and the personid is 45130
# the tournament id is 1686 and the personid is 59658
# the tournament id is 1686 and the personid is 51480
# the tournament id is 1686 and the personid is 56630
# the tournament id is 1686 and the personid is 59436
# the tournament id is 1686 and the personid is 54312
# the tournament id is 1686 and the personid is 54992
# the tournament id is 1686 and the personid is 44196
# the tournament id is 1686 and the personid is 54102
# the tournament id is 1686 and the personid is 51654
# the tournament id is 1686 and the personid is 59348
# the tournament id is 1686 and the personid is 59660
# the tournament id is 1686 and the personid is 54737
# the tournament id is 1686 and the personid is 38829
# the tournament id is 1686 and the personid is 47215
# the tournament id is 1686 and the personid is 59650
# the tournament id is 1686 and the personid is 57695
# the tournament id is 1686 and the personid is 51671
# the tournament id is 1686 and the personid is 59643
# the tournament id is 1686 and the personid is 47432
# the tournament id is 1686 and the personid is 38138
# the tournament id is 1686 and the personid is 54260
# the tournament id is 1686 and the personid is 56593
# the tournament id is 1686 and the personid is 35836
# the tournament id is 1686 and the personid is 55783
# the tournament id is 1686 and the personid is 59659
# the tournament id is 1686 and the personid is 55227
# the tournament id is 1686 and the personid is 31674
# the tournament id is 1686 and the personid is 54681
# the tournament id is 1686 and the personid is 42988
# the tournament id is 1686 and the personid is 44938
# the tournament id is 1686 and the personid is 45693
# the tournament id is 1686 and the personid is 59400
# the tournament id is 1686 and the personid is 49917
# the tournament id is 1686 and the personid is 54980
# the tournament id is 1686 and the personid is 59361
# the tournament id is 1686 and the personid is 48842
# the tournament id is 1686 and the personid is 56544
# the tournament id is 1686 and the personid is 54944
# the tournament id is 1686 and the personid is 42464
# the tournament id is 1686 and the personid is 59430
# the tournament id is 1686 and the personid is 52263
# the tournament id is 1686 and the personid is 46038
# the tournament id is 1686 and the personid is 59411
# the tournament id is 1687
# the tournament id is 1687 and the personid is 55785
# the tournament id is 1687 and the personid is 54758
# the tournament id is 1687 and the personid is 36561
# the tournament id is 1687 and the personid is 57163
# the tournament id is 1687 and the personid is 49046
# the tournament id is 1687 and the personid is 53380
# the tournament id is 1687 and the personid is 50538
# the tournament id is 1687 and the personid is 54678
# the tournament id is 1687 and the personid is 57353
# the tournament id is 1687 and the personid is 55027
# the tournament id is 1687 and the personid is 39694
# the tournament id is 1687 and the personid is 48550
# the tournament id is 1687 and the personid is 59648
# the tournament id is 1687 and the personid is 59798
# the tournament id is 1687 and the personid is 58720
# the tournament id is 1687 and the personid is 51742
# the tournament id is 1687 and the personid is 59795
# the tournament id is 1687 and the personid is 52675
# the tournament id is 1687 and the personid is 54728
# the tournament id is 1687 and the personid is 29071
# the tournament id is 1687 and the personid is 59641
# the tournament id is 1687 and the personid is 51604
# the tournament id is 1687 and the personid is 52662
# the tournament id is 1687 and the personid is 59428
# the tournament id is 1687 and the personid is 51362
# the tournament id is 1687 and the personid is 52549
# the tournament id is 1687 and the personid is 43474
# the tournament id is 1687 and the personid is 54679
# the tournament id is 1687 and the personid is 57156
# the tournament id is 1687 and the personid is 52436
# the tournament id is 1687 and the personid is 54200
# the tournament id is 1687 and the personid is 59366
# the tournament id is 1687 and the personid is 52851
# the tournament id is 1687 and the personid is 56563
# the tournament id is 1687 and the personid is 42991
# the tournament id is 1687 and the personid is 56552
# the tournament id is 1687 and the personid is 36055
# the tournament id is 1687 and the personid is 51278
# the tournament id is 1687 and the personid is 50593
# the tournament id is 1687 and the personid is 29397
# the tournament id is 1687 and the personid is 43088
# the tournament id is 1687 and the personid is 49529
# the tournament id is 1687 and the personid is 49125
# the tournament id is 1687 and the personid is 48789
# the tournament id is 1687 and the personid is 56571
# the tournament id is 1687 and the personid is 54104
# the tournament id is 1687 and the personid is 32150
# the tournament id is 1687 and the personid is 39111
# the tournament id is 1687 and the personid is 50766
# the tournament id is 1687 and the personid is 59429
# the tournament id is 1687 and the personid is 59476
# the tournament id is 1687 and the personid is 59655
# the tournament id is 1687 and the personid is 52706
# the tournament id is 1687 and the personid is 47437
# the tournament id is 1687 and the personid is 52800
# the tournament id is 1687 and the personid is 59651
# the tournament id is 1687 and the personid is 56614
# the tournament id is 1687 and the personid is 49224
# the tournament id is 1687 and the personid is 52277
# the tournament id is 1687 and the personid is 54261
# the tournament id is 1687 and the personid is 48567
# the tournament id is 1687 and the personid is 59639
# the tournament id is 1687 and the personid is 50326
# the tournament id is 1687 and the personid is 51118
# the tournament id is 1687 and the personid is 48983
# the tournament id is 1687 and the personid is 46233
# the tournament id is 1687 and the personid is 45510
# the tournament id is 1687 and the personid is 59365
# the tournament id is 1687 and the personid is 54198
# the tournament id is 1687 and the personid is 55780
# the tournament id is 1687 and the personid is 59638
# the tournament id is 1687 and the personid is 59352
# the tournament id is 1687 and the personid is 59640
# the tournament id is 1687 and the personid is 59647
# the tournament id is 1687 and the personid is 44113
# the tournament id is 1687 and the personid is 30554
# the tournament id is 1687 and the personid is 54085
# the tournament id is 1687 and the personid is 51788
# the tournament id is 1687 and the personid is 52840
# the tournament id is 1687 and the personid is 52241
# the tournament id is 1687 and the personid is 51552
# the tournament id is 1687 and the personid is 59369
# the tournament id is 1687 and the personid is 27056
# the tournament id is 1687 and the personid is 55641
# the tournament id is 1687 and the personid is 20830
# the tournament id is 1687 and the personid is 59653
# the tournament id is 1687 and the personid is 57702
# the tournament id is 1687 and the personid is 48980
# the tournament id is 1687 and the personid is 52266
# the tournament id is 1687 and the personid is 59644
# the tournament id is 1687 and the personid is 50319
# the tournament id is 1687 and the personid is 54252
# the tournament id is 1687 and the personid is 59479
# the tournament id is 1687 and the personid is 59656
# the tournament id is 1687 and the personid is 43174
# the tournament id is 1687 and the personid is 52350
# the tournament id is 1687 and the personid is 57843
# the tournament id is 1687 and the personid is 56577
# the tournament id is 1687 and the personid is 59360
# the tournament id is 1687 and the personid is 59645
# the tournament id is 1687 and the personid is 59652
# the tournament id is 1687 and the personid is 45717
# the tournament id is 1687 and the personid is 51523
# the tournament id is 1687 and the personid is 52181
# the tournament id is 1687 and the personid is 52824
# the tournament id is 1687 and the personid is 53267
# the tournament id is 1687 and the personid is 54282
# the tournament id is 1687 and the personid is 57295
# the tournament id is 1687 and the personid is 56609
# the tournament id is 1687 and the personid is 45506
# the tournament id is 1687 and the personid is 56598
# the tournament id is 1687 and the personid is 52312
# the tournament id is 1687 and the personid is 52291
# the tournament id is 1687 and the personid is 52384
# the tournament id is 1687 and the personid is 59376
# the tournament id is 1687 and the personid is 59662
# the tournament id is 1687 and the personid is 59424
# the tournament id is 1687 and the personid is 59642
# the tournament id is 1687 and the personid is 51662
# the tournament id is 1687 and the personid is 55658
# the tournament id is 1687 and the personid is 45192
# the tournament id is 1687 and the personid is 59389
# the tournament id is 1687 and the personid is 59793
# the tournament id is 1687 and the personid is 59354
# the tournament id is 1687 and the personid is 52997
# the tournament id is 1687 and the personid is 54287
# the tournament id is 1687 and the personid is 39659
# the tournament id is 1687 and the personid is 53260
# the tournament id is 1687 and the personid is 52625
# the tournament id is 1687 and the personid is 44109
# the tournament id is 1687 and the personid is 54989
# the tournament id is 1687 and the personid is 56548
# the tournament id is 1687 and the personid is 59426
# the tournament id is 1687 and the personid is 53333
# the tournament id is 1687 and the personid is 57162
# the tournament id is 1687 and the personid is 48582
# the tournament id is 1687 and the personid is 59646
# the tournament id is 1687 and the personid is 32541
# the tournament id is 1687 and the personid is 56579
# the tournament id is 1687 and the personid is 48840
# the tournament id is 1687 and the personid is 57157
# the tournament id is 1687 and the personid is 46475
# the tournament id is 1687 and the personid is 33406
# the tournament id is 1687 and the personid is 51080
# the tournament id is 1687 and the personid is 59654
# the tournament id is 1687 and the personid is 48360
# the tournament id is 1687 and the personid is 55574
# the tournament id is 1687 and the personid is 51099
# the tournament id is 1687 and the personid is 59403
# the tournament id is 1687 and the personid is 52829
# the tournament id is 1687 and the personid is 52894
# the tournament id is 1687 and the personid is 26802
# the tournament id is 1687 and the personid is 59353
# the tournament id is 1687 and the personid is 46033
# the tournament id is 1687 and the personid is 53249
# the tournament id is 1687 and the personid is 56575
# the tournament id is 1687 and the personid is 45130
# the tournament id is 1687 and the personid is 59658
# the tournament id is 1687 and the personid is 51480
# the tournament id is 1687 and the personid is 56630
# the tournament id is 1687 and the personid is 59436
# the tournament id is 1687 and the personid is 54312
# the tournament id is 1687 and the personid is 59401
# the tournament id is 1687 and the personid is 54992
# the tournament id is 1687 and the personid is 44196
# the tournament id is 1687 and the personid is 54102
# the tournament id is 1687 and the personid is 51654
# the tournament id is 1687 and the personid is 59348
# the tournament id is 1687 and the personid is 54737
# the tournament id is 1687 and the personid is 59660
# the tournament id is 1687 and the personid is 47215
# the tournament id is 1687 and the personid is 59650
# the tournament id is 1687 and the personid is 57695
# the tournament id is 1687 and the personid is 51671
# the tournament id is 1687 and the personid is 59643
# the tournament id is 1687 and the personid is 57161
# the tournament id is 1687 and the personid is 47432
# the tournament id is 1687 and the personid is 38138
# the tournament id is 1687 and the personid is 52288
# the tournament id is 1687 and the personid is 54260
# the tournament id is 1687 and the personid is 59796
# the tournament id is 1687 and the personid is 56593
# the tournament id is 1687 and the personid is 35836
# the tournament id is 1687 and the personid is 55783
# the tournament id is 1687 and the personid is 59797
# the tournament id is 1687 and the personid is 55227
# the tournament id is 1687 and the personid is 59659
# the tournament id is 1687 and the personid is 31674
# the tournament id is 1687 and the personid is 53291
# the tournament id is 1687 and the personid is 54681
# the tournament id is 1687 and the personid is 42988
# the tournament id is 1687 and the personid is 45693
# the tournament id is 1687 and the personid is 44938
# the tournament id is 1687 and the personid is 32657
# the tournament id is 1687 and the personid is 59400
# the tournament id is 1687 and the personid is 56553
# the tournament id is 1687 and the personid is 49917
# the tournament id is 1687 and the personid is 54980
# the tournament id is 1687 and the personid is 59794
# the tournament id is 1687 and the personid is 48842
# the tournament id is 1687 and the personid is 59361
# the tournament id is 1687 and the personid is 56544
# the tournament id is 1687 and the personid is 59430
# the tournament id is 1687 and the personid is 52263
# the tournament id is 1687 and the personid is 46038
# the tournament id is 1687 and the personid is 51331
# the tournament id is 1687 and the personid is 59411
# the tournament id is 1688
# the tournament id is 1688 and the personid is 57152
# the tournament id is 1688 and the personid is 57163
# the tournament id is 1688 and the personid is 51385
# the tournament id is 1688 and the personid is 49046
# the tournament id is 1688 and the personid is 50538
# the tournament id is 1688 and the personid is 59967
# the tournament id is 1688 and the personid is 35531
# the tournament id is 1688 and the personid is 59968
# the tournament id is 1688 and the personid is 39694
# the tournament id is 1688 and the personid is 58720
# the tournament id is 1688 and the personid is 54297
# the tournament id is 1688 and the personid is 51742
# the tournament id is 1688 and the personid is 32149
# the tournament id is 1688 and the personid is 52675
# the tournament id is 1688 and the personid is 29071
# the tournament id is 1688 and the personid is 54728
# the tournament id is 1688 and the personid is 51604
# the tournament id is 1688 and the personid is 52662
# the tournament id is 1688 and the personid is 52549
# the tournament id is 1688 and the personid is 51362
# the tournament id is 1688 and the personid is 43474
# the tournament id is 1688 and the personid is 54679
# the tournament id is 1688 and the personid is 59434
# the tournament id is 1688 and the personid is 57156
# the tournament id is 1688 and the personid is 52436
# the tournament id is 1688 and the personid is 59366
# the tournament id is 1688 and the personid is 56563
# the tournament id is 1688 and the personid is 52851
# the tournament id is 1688 and the personid is 42991
# the tournament id is 1688 and the personid is 56552
# the tournament id is 1688 and the personid is 51278
# the tournament id is 1688 and the personid is 36055
# the tournament id is 1688 and the personid is 50593
# the tournament id is 1688 and the personid is 29397
# the tournament id is 1688 and the personid is 43088
# the tournament id is 1688 and the personid is 49529
# the tournament id is 1688 and the personid is 49125
# the tournament id is 1688 and the personid is 48789
# the tournament id is 1688 and the personid is 32150
# the tournament id is 1688 and the personid is 56571
# the tournament id is 1688 and the personid is 39111
# the tournament id is 1688 and the personid is 59969
# the tournament id is 1688 and the personid is 50766
# the tournament id is 1688 and the personid is 52216
# the tournament id is 1688 and the personid is 59429
# the tournament id is 1688 and the personid is 59972
# the tournament id is 1688 and the personid is 43532
# the tournament id is 1688 and the personid is 51780
# the tournament id is 1688 and the personid is 52706
# the tournament id is 1688 and the personid is 47437
# the tournament id is 1688 and the personid is 59651
# the tournament id is 1688 and the personid is 52800
# the tournament id is 1688 and the personid is 56614
# the tournament id is 1688 and the personid is 54943
# the tournament id is 1688 and the personid is 49224
# the tournament id is 1688 and the personid is 52277
# the tournament id is 1688 and the personid is 54261
# the tournament id is 1688 and the personid is 48567
# the tournament id is 1688 and the personid is 59639
# the tournament id is 1688 and the personid is 50326
# the tournament id is 1688 and the personid is 51118
# the tournament id is 1688 and the personid is 48983
# the tournament id is 1688 and the personid is 45510
# the tournament id is 1688 and the personid is 55780
# the tournament id is 1688 and the personid is 59638
# the tournament id is 1688 and the personid is 59640
# the tournament id is 1688 and the personid is 59647
# the tournament id is 1688 and the personid is 44113
# the tournament id is 1688 and the personid is 54085
# the tournament id is 1688 and the personid is 51788
# the tournament id is 1688 and the personid is 52241
# the tournament id is 1688 and the personid is 27056
# the tournament id is 1688 and the personid is 57702
# the tournament id is 1688 and the personid is 52266
# the tournament id is 1688 and the personid is 51613
# the tournament id is 1688 and the personid is 55216
# the tournament id is 1688 and the personid is 29030
# the tournament id is 1688 and the personid is 54252
# the tournament id is 1688 and the personid is 48556
# the tournament id is 1688 and the personid is 59649
# the tournament id is 1688 and the personid is 43174
# the tournament id is 1688 and the personid is 52350
# the tournament id is 1688 and the personid is 57843
# the tournament id is 1688 and the personid is 56577
# the tournament id is 1688 and the personid is 59360
# the tournament id is 1688 and the personid is 45717
# the tournament id is 1688 and the personid is 51523
# the tournament id is 1688 and the personid is 48721
# the tournament id is 1688 and the personid is 52181
# the tournament id is 1688 and the personid is 51965
# the tournament id is 1688 and the personid is 53267
# the tournament id is 1688 and the personid is 45975
# the tournament id is 1688 and the personid is 32190
# the tournament id is 1688 and the personid is 54282
# the tournament id is 1688 and the personid is 57295
# the tournament id is 1688 and the personid is 56609
# the tournament id is 1688 and the personid is 53295
# the tournament id is 1688 and the personid is 52291
# the tournament id is 1688 and the personid is 45506
# the tournament id is 1688 and the personid is 52312
# the tournament id is 1688 and the personid is 52384
# the tournament id is 1688 and the personid is 59642
# the tournament id is 1688 and the personid is 59424
# the tournament id is 1688 and the personid is 37016
# the tournament id is 1688 and the personid is 56608
# the tournament id is 1688 and the personid is 40061
# the tournament id is 1688 and the personid is 51662
# the tournament id is 1688 and the personid is 45192
# the tournament id is 1688 and the personid is 59793
# the tournament id is 1688 and the personid is 59354
# the tournament id is 1688 and the personid is 54287
# the tournament id is 1688 and the personid is 39659
# the tournament id is 1688 and the personid is 33690
# the tournament id is 1688 and the personid is 53260
# the tournament id is 1688 and the personid is 55225
# the tournament id is 1688 and the personid is 44109
# the tournament id is 1688 and the personid is 34168
# the tournament id is 1688 and the personid is 56548
# the tournament id is 1688 and the personid is 58361
# the tournament id is 1688 and the personid is 53333
# the tournament id is 1688 and the personid is 59426
# the tournament id is 1688 and the personid is 59646
# the tournament id is 1688 and the personid is 32541
# the tournament id is 1688 and the personid is 54693
# the tournament id is 1688 and the personid is 59973
# the tournament id is 1688 and the personid is 57157
# the tournament id is 1688 and the personid is 46475
# the tournament id is 1688 and the personid is 57320
# the tournament id is 1688 and the personid is 51080
# the tournament id is 1688 and the personid is 33406
# the tournament id is 1688 and the personid is 59976
# the tournament id is 1688 and the personid is 48360
# the tournament id is 1688 and the personid is 59403
# the tournament id is 1688 and the personid is 52829
# the tournament id is 1688 and the personid is 52894
# the tournament id is 1688 and the personid is 26802
# the tournament id is 1688 and the personid is 46033
# the tournament id is 1688 and the personid is 59353
# the tournament id is 1688 and the personid is 53249
# the tournament id is 1688 and the personid is 56575
# the tournament id is 1688 and the personid is 59658
# the tournament id is 1688 and the personid is 45130
# the tournament id is 1688 and the personid is 32332
# the tournament id is 1688 and the personid is 56630
# the tournament id is 1688 and the personid is 59436
# the tournament id is 1688 and the personid is 54992
# the tournament id is 1688 and the personid is 44196
# the tournament id is 1688 and the personid is 59500
# the tournament id is 1688 and the personid is 56594
# the tournament id is 1688 and the personid is 51654
# the tournament id is 1688 and the personid is 59348
# the tournament id is 1688 and the personid is 54737
# the tournament id is 1688 and the personid is 38829
# the tournament id is 1688 and the personid is 47215
# the tournament id is 1688 and the personid is 59650
# the tournament id is 1688 and the personid is 59975
# the tournament id is 1688 and the personid is 57695
# the tournament id is 1688 and the personid is 51671
# the tournament id is 1688 and the personid is 59643
# the tournament id is 1688 and the personid is 57161
# the tournament id is 1688 and the personid is 47432
# the tournament id is 1688 and the personid is 38138
# the tournament id is 1688 and the personid is 45625
# the tournament id is 1688 and the personid is 57253
# the tournament id is 1688 and the personid is 54260
# the tournament id is 1688 and the personid is 59796
# the tournament id is 1688 and the personid is 56593
# the tournament id is 1688 and the personid is 55783
# the tournament id is 1688 and the personid is 54681
# the tournament id is 1688 and the personid is 31674
# the tournament id is 1688 and the personid is 54732
# the tournament id is 1688 and the personid is 42988
# the tournament id is 1688 and the personid is 32333
# the tournament id is 1688 and the personid is 45693
# the tournament id is 1688 and the personid is 47808
# the tournament id is 1688 and the personid is 59400
# the tournament id is 1688 and the personid is 32657
# the tournament id is 1688 and the personid is 49917
# the tournament id is 1688 and the personid is 59794
# the tournament id is 1688 and the personid is 51903
# the tournament id is 1688 and the personid is 54980
# the tournament id is 1688 and the personid is 48842
# the tournament id is 1688 and the personid is 57326
# the tournament id is 1688 and the personid is 59971
# the tournament id is 1688 and the personid is 33687
# the tournament id is 1688 and the personid is 56544
# the tournament id is 1688 and the personid is 59397
# the tournament id is 1688 and the personid is 52263
# the tournament id is 1688 and the personid is 46038
# the tournament id is 1688 and the personid is 51330
# the tournament id is 1688 and the personid is 59430
# the tournament id is 1688 and the personid is 59411
# the tournament id is 1689
# the tournament id is 1689 and the personid is 55785
# the tournament id is 1689 and the personid is 57152
# the tournament id is 1689 and the personid is 36561
# the tournament id is 1689 and the personid is 51385
# the tournament id is 1689 and the personid is 49046
# the tournament id is 1689 and the personid is 50538
# the tournament id is 1689 and the personid is 59967
# the tournament id is 1689 and the personid is 35531
# the tournament id is 1689 and the personid is 59968
# the tournament id is 1689 and the personid is 39694
# the tournament id is 1689 and the personid is 52213
# the tournament id is 1689 and the personid is 58720
# the tournament id is 1689 and the personid is 54297
# the tournament id is 1689 and the personid is 51742
# the tournament id is 1689 and the personid is 32149
# the tournament id is 1689 and the personid is 54728
# the tournament id is 1689 and the personid is 29071
# the tournament id is 1689 and the personid is 59641
# the tournament id is 1689 and the personid is 51604
# the tournament id is 1689 and the personid is 52549
# the tournament id is 1689 and the personid is 51362
# the tournament id is 1689 and the personid is 43474
# the tournament id is 1689 and the personid is 59989
# the tournament id is 1689 and the personid is 54679
# the tournament id is 1689 and the personid is 59434
# the tournament id is 1689 and the personid is 59373
# the tournament id is 1689 and the personid is 57156
# the tournament id is 1689 and the personid is 52436
# the tournament id is 1689 and the personid is 59366
# the tournament id is 1689 and the personid is 56563
# the tournament id is 1689 and the personid is 49354
# the tournament id is 1689 and the personid is 42991
# the tournament id is 1689 and the personid is 56552
# the tournament id is 1689 and the personid is 51278
# the tournament id is 1689 and the personid is 50593
# the tournament id is 1689 and the personid is 29397
# the tournament id is 1689 and the personid is 43088
# the tournament id is 1689 and the personid is 49529
# the tournament id is 1689 and the personid is 49125
# the tournament id is 1689 and the personid is 60002
# the tournament id is 1689 and the personid is 48789
# the tournament id is 1689 and the personid is 56571
# the tournament id is 1689 and the personid is 54104
# the tournament id is 1689 and the personid is 32150
# the tournament id is 1689 and the personid is 39111
# the tournament id is 1689 and the personid is 59969
# the tournament id is 1689 and the personid is 59977
# the tournament id is 1689 and the personid is 52216
# the tournament id is 1689 and the personid is 50766
# the tournament id is 1689 and the personid is 59429
# the tournament id is 1689 and the personid is 59972
# the tournament id is 1689 and the personid is 51780
# the tournament id is 1689 and the personid is 52706
# the tournament id is 1689 and the personid is 47437
# the tournament id is 1689 and the personid is 52800
# the tournament id is 1689 and the personid is 59651
# the tournament id is 1689 and the personid is 56614
# the tournament id is 1689 and the personid is 54943
# the tournament id is 1689 and the personid is 49224
# the tournament id is 1689 and the personid is 52277
# the tournament id is 1689 and the personid is 43446
# the tournament id is 1689 and the personid is 54261
# the tournament id is 1689 and the personid is 59639
# the tournament id is 1689 and the personid is 50326
# the tournament id is 1689 and the personid is 51118
# the tournament id is 1689 and the personid is 48983
# the tournament id is 1689 and the personid is 45510
# the tournament id is 1689 and the personid is 45589
# the tournament id is 1689 and the personid is 55692
# the tournament id is 1689 and the personid is 59638
# the tournament id is 1689 and the personid is 59990
# the tournament id is 1689 and the personid is 55780
# the tournament id is 1689 and the personid is 59352
# the tournament id is 1689 and the personid is 59640
# the tournament id is 1689 and the personid is 57844
# the tournament id is 1689 and the personid is 59647
# the tournament id is 1689 and the personid is 44113
# the tournament id is 1689 and the personid is 54085
# the tournament id is 1689 and the personid is 51788
# the tournament id is 1689 and the personid is 54283
# the tournament id is 1689 and the personid is 27056
# the tournament id is 1689 and the personid is 20830
# the tournament id is 1689 and the personid is 57702
# the tournament id is 1689 and the personid is 48980
# the tournament id is 1689 and the personid is 52266
# the tournament id is 1689 and the personid is 51613
# the tournament id is 1689 and the personid is 55216
# the tournament id is 1689 and the personid is 29030
# the tournament id is 1689 and the personid is 54252
# the tournament id is 1689 and the personid is 59649
# the tournament id is 1689 and the personid is 43174
# the tournament id is 1689 and the personid is 52350
# the tournament id is 1689 and the personid is 57843
# the tournament id is 1689 and the personid is 59360
# the tournament id is 1689 and the personid is 45717
# the tournament id is 1689 and the personid is 51523
# the tournament id is 1689 and the personid is 52181
# the tournament id is 1689 and the personid is 48721
# the tournament id is 1689 and the personid is 59410
# the tournament id is 1689 and the personid is 51965
# the tournament id is 1689 and the personid is 52824
# the tournament id is 1689 and the personid is 53267
# the tournament id is 1689 and the personid is 45975
# the tournament id is 1689 and the personid is 59435
# the tournament id is 1689 and the personid is 32190
# the tournament id is 1689 and the personid is 54282
# the tournament id is 1689 and the personid is 57295
# the tournament id is 1689 and the personid is 53295
# the tournament id is 1689 and the personid is 56609
# the tournament id is 1689 and the personid is 45506
# the tournament id is 1689 and the personid is 52312
# the tournament id is 1689 and the personid is 59974
# the tournament id is 1689 and the personid is 52291
# the tournament id is 1689 and the personid is 52384
# the tournament id is 1689 and the personid is 59376
# the tournament id is 1689 and the personid is 59642
# the tournament id is 1689 and the personid is 59424
# the tournament id is 1689 and the personid is 56608
# the tournament id is 1689 and the personid is 40061
# the tournament id is 1689 and the personid is 51662
# the tournament id is 1689 and the personid is 45192
# the tournament id is 1689 and the personid is 59389
# the tournament id is 1689 and the personid is 59793
# the tournament id is 1689 and the personid is 59354
# the tournament id is 1689 and the personid is 54287
# the tournament id is 1689 and the personid is 39659
# the tournament id is 1689 and the personid is 53260
# the tournament id is 1689 and the personid is 33690
# the tournament id is 1689 and the personid is 44109
# the tournament id is 1689 and the personid is 55225
# the tournament id is 1689 and the personid is 34168
# the tournament id is 1689 and the personid is 56548
# the tournament id is 1689 and the personid is 54989
# the tournament id is 1689 and the personid is 58361
# the tournament id is 1689 and the personid is 53333
# the tournament id is 1689 and the personid is 59426
# the tournament id is 1689 and the personid is 59646
# the tournament id is 1689 and the personid is 54693
# the tournament id is 1689 and the personid is 56579
# the tournament id is 1689 and the personid is 46475
# the tournament id is 1689 and the personid is 57157
# the tournament id is 1689 and the personid is 55784
# the tournament id is 1689 and the personid is 33406
# the tournament id is 1689 and the personid is 57320
# the tournament id is 1689 and the personid is 51080
# the tournament id is 1689 and the personid is 59976
# the tournament id is 1689 and the personid is 48360
# the tournament id is 1689 and the personid is 59403
# the tournament id is 1689 and the personid is 52829
# the tournament id is 1689 and the personid is 52894
# the tournament id is 1689 and the personid is 26802
# the tournament id is 1689 and the personid is 59353
# the tournament id is 1689 and the personid is 46033
# the tournament id is 1689 and the personid is 53249
# the tournament id is 1689 and the personid is 46458
# the tournament id is 1689 and the personid is 56575
# the tournament id is 1689 and the personid is 45130
# the tournament id is 1689 and the personid is 59658
# the tournament id is 1689 and the personid is 32332
# the tournament id is 1689 and the personid is 56630
# the tournament id is 1689 and the personid is 59436
# the tournament id is 1689 and the personid is 54992
# the tournament id is 1689 and the personid is 44196
# the tournament id is 1689 and the personid is 59500
# the tournament id is 1689 and the personid is 56594
# the tournament id is 1689 and the personid is 59970
# the tournament id is 1689 and the personid is 54737
# the tournament id is 1689 and the personid is 38829
# the tournament id is 1689 and the personid is 47215
# the tournament id is 1689 and the personid is 59650
# the tournament id is 1689 and the personid is 59975
# the tournament id is 1689 and the personid is 57695
# the tournament id is 1689 and the personid is 51671
# the tournament id is 1689 and the personid is 57161
# the tournament id is 1689 and the personid is 59643
# the tournament id is 1689 and the personid is 47432
# the tournament id is 1689 and the personid is 38138
# the tournament id is 1689 and the personid is 60003
# the tournament id is 1689 and the personid is 54260
# the tournament id is 1689 and the personid is 57253
# the tournament id is 1689 and the personid is 45625
# the tournament id is 1689 and the personid is 59796
# the tournament id is 1689 and the personid is 56593
# the tournament id is 1689 and the personid is 55783
# the tournament id is 1689 and the personid is 31674
# the tournament id is 1689 and the personid is 54681
# the tournament id is 1689 and the personid is 54732
# the tournament id is 1689 and the personid is 42988
# the tournament id is 1689 and the personid is 47808
# the tournament id is 1689 and the personid is 45693
# the tournament id is 1689 and the personid is 56553
# the tournament id is 1689 and the personid is 32657
# the tournament id is 1689 and the personid is 49917
# the tournament id is 1689 and the personid is 51903
# the tournament id is 1689 and the personid is 59794
# the tournament id is 1689 and the personid is 54980
# the tournament id is 1689 and the personid is 59971
# the tournament id is 1689 and the personid is 48842
# the tournament id is 1689 and the personid is 33687
# the tournament id is 1689 and the personid is 56544
# the tournament id is 1689 and the personid is 59397
# the tournament id is 1689 and the personid is 51330
# the tournament id is 1689 and the personid is 59430
# the tournament id is 1689 and the personid is 46038
# the tournament id is 1689 and the personid is 59411
# the tournament id is 1690
# the tournament id is 1690 and the personid is 36561
# the tournament id is 1690 and the personid is 57163
# the tournament id is 1690 and the personid is 58389
# the tournament id is 1690 and the personid is 50538
# the tournament id is 1690 and the personid is 53380
# the tournament id is 1690 and the personid is 55027
# the tournament id is 1690 and the personid is 39694
# the tournament id is 1690 and the personid is 52213
# the tournament id is 1690 and the personid is 54297
# the tournament id is 1690 and the personid is 51742
# the tournament id is 1690 and the personid is 32149
# the tournament id is 1690 and the personid is 48529
# the tournament id is 1690 and the personid is 60226
# the tournament id is 1690 and the personid is 52675
# the tournament id is 1690 and the personid is 29071
# the tournament id is 1690 and the personid is 54728
# the tournament id is 1690 and the personid is 60222
# the tournament id is 1690 and the personid is 42461
# the tournament id is 1690 and the personid is 51604
# the tournament id is 1690 and the personid is 52662
# the tournament id is 1690 and the personid is 52549
# the tournament id is 1690 and the personid is 51362
# the tournament id is 1690 and the personid is 43474
# the tournament id is 1690 and the personid is 60234
# the tournament id is 1690 and the personid is 54246
# the tournament id is 1690 and the personid is 54679
# the tournament id is 1690 and the personid is 59434
# the tournament id is 1690 and the personid is 57156
# the tournament id is 1690 and the personid is 52436
# the tournament id is 1690 and the personid is 59366
# the tournament id is 1690 and the personid is 56563
# the tournament id is 1690 and the personid is 52851
# the tournament id is 1690 and the personid is 56552
# the tournament id is 1690 and the personid is 36055
# the tournament id is 1690 and the personid is 51278
# the tournament id is 1690 and the personid is 55646
# the tournament id is 1690 and the personid is 50593
# the tournament id is 1690 and the personid is 56622
# the tournament id is 1690 and the personid is 29397
# the tournament id is 1690 and the personid is 43088
# the tournament id is 1690 and the personid is 49529
# the tournament id is 1690 and the personid is 48789
# the tournament id is 1690 and the personid is 56571
# the tournament id is 1690 and the personid is 32150
# the tournament id is 1690 and the personid is 54104
# the tournament id is 1690 and the personid is 52216
# the tournament id is 1690 and the personid is 59977
# the tournament id is 1690 and the personid is 50766
# the tournament id is 1690 and the personid is 59429
# the tournament id is 1690 and the personid is 59972
# the tournament id is 1690 and the personid is 51780
# the tournament id is 1690 and the personid is 52706
# the tournament id is 1690 and the personid is 47437
# the tournament id is 1690 and the personid is 52800
# the tournament id is 1690 and the personid is 59651
# the tournament id is 1690 and the personid is 49224
# the tournament id is 1690 and the personid is 52277
# the tournament id is 1690 and the personid is 60237
# the tournament id is 1690 and the personid is 43446
# the tournament id is 1690 and the personid is 54261
# the tournament id is 1690 and the personid is 51118
# the tournament id is 1690 and the personid is 48983
# the tournament id is 1690 and the personid is 60225
# the tournament id is 1690 and the personid is 60230
# the tournament id is 1690 and the personid is 55780
# the tournament id is 1690 and the personid is 59638
# the tournament id is 1690 and the personid is 58388
# the tournament id is 1690 and the personid is 57844
# the tournament id is 1690 and the personid is 59647
# the tournament id is 1690 and the personid is 44113
# the tournament id is 1690 and the personid is 60227
# the tournament id is 1690 and the personid is 60236
# the tournament id is 1690 and the personid is 54085
# the tournament id is 1690 and the personid is 59369
# the tournament id is 1690 and the personid is 60228
# the tournament id is 1690 and the personid is 28585
# the tournament id is 1690 and the personid is 57702
# the tournament id is 1690 and the personid is 48980
# the tournament id is 1690 and the personid is 52266
# the tournament id is 1690 and the personid is 51613
# the tournament id is 1690 and the personid is 55216
# the tournament id is 1690 and the personid is 50319
# the tournament id is 1690 and the personid is 29030
# the tournament id is 1690 and the personid is 54252
# the tournament id is 1690 and the personid is 59479
# the tournament id is 1690 and the personid is 43174
# the tournament id is 1690 and the personid is 52350
# the tournament id is 1690 and the personid is 57843
# the tournament id is 1690 and the personid is 56577
# the tournament id is 1690 and the personid is 59360
# the tournament id is 1690 and the personid is 45717
# the tournament id is 1690 and the personid is 51523
# the tournament id is 1690 and the personid is 55841
# the tournament id is 1690 and the personid is 48721
# the tournament id is 1690 and the personid is 51965
# the tournament id is 1690 and the personid is 59410
# the tournament id is 1690 and the personid is 28965
# the tournament id is 1690 and the personid is 53267
# the tournament id is 1690 and the personid is 59435
# the tournament id is 1690 and the personid is 54282
# the tournament id is 1690 and the personid is 57295
# the tournament id is 1690 and the personid is 53295
# the tournament id is 1690 and the personid is 56609
# the tournament id is 1690 and the personid is 52312
# the tournament id is 1690 and the personid is 45506
# the tournament id is 1690 and the personid is 56598
# the tournament id is 1690 and the personid is 59974
# the tournament id is 1690 and the personid is 52291
# the tournament id is 1690 and the personid is 59376
# the tournament id is 1690 and the personid is 52384
# the tournament id is 1690 and the personid is 48658
# the tournament id is 1690 and the personid is 59642
# the tournament id is 1690 and the personid is 59424
# the tournament id is 1690 and the personid is 40061
# the tournament id is 1690 and the personid is 51662
# the tournament id is 1690 and the personid is 45192
# the tournament id is 1690 and the personid is 59389
# the tournament id is 1690 and the personid is 59354
# the tournament id is 1690 and the personid is 54287
# the tournament id is 1690 and the personid is 39659
# the tournament id is 1690 and the personid is 52625
# the tournament id is 1690 and the personid is 44109
# the tournament id is 1690 and the personid is 34168
# the tournament id is 1690 and the personid is 54989
# ...
# the tournament id is 1692 and the personid is 50319
# the tournament id is 1692 and the personid is 55216
# the tournament id is 1692 and the personid is 54252
# the tournament id is 1692 and the personid is 59649
# the tournament id is 1692 and the personid is 59479
# the tournament id is 1692 and the personid is 43174
# the tournament id is 1692 and the personid is 52350
# the tournament id is 1692 and the personid is 56577
# the tournament id is 1692 and the personid is 59360
# the tournament id is 1692 and the personid is 51523
# the tournament id is 1692 and the personid is 55841
# the tournament id is 1692 and the personid is 48721
# the tournament id is 1692 and the personid is 59410
# the tournament id is 1692 and the personid is 49628
# the tournament id is 1692 and the personid is 53267
# the tournament id is 1692 and the personid is 28965
# the tournament id is 1692 and the personid is 54282
# the tournament id is 1692 and the personid is 57295
# the tournament id is 1692 and the personid is 53295
# the tournament id is 1692 and the personid is 56609
# the tournament id is 1692 and the personid is 52312
# the tournament id is 1692 and the personid is 45506
# the tournament id is 1692 and the personid is 56598
# the tournament id is 1692 and the personid is 52291
# the tournament id is 1692 and the personid is 52384
# the tournament id is 1692 and the personid is 48658
# the tournament id is 1692 and the personid is 59642
# the tournament id is 1692 and the personid is 59424
# the tournament id is 1692 and the personid is 40061
# the tournament id is 1692 and the personid is 48058
# the tournament id is 1692 and the personid is 60694
# the tournament id is 1692 and the personid is 51662
# the tournament id is 1692 and the personid is 60687
# the tournament id is 1692 and the personid is 60695
# the tournament id is 1692 and the personid is 59354
# the tournament id is 1692 and the personid is 54287
# the tournament id is 1692 and the personid is 52625
# the tournament id is 1692 and the personid is 39659
# the tournament id is 1692 and the personid is 54989
# the tournament id is 1692 and the personid is 34168
# the tournament id is 1692 and the personid is 53333
# the tournament id is 1692 and the personid is 59426
# the tournament id is 1692 and the personid is 60223
# the tournament id is 1692 and the personid is 59646
# the tournament id is 1692 and the personid is 60239
# the tournament id is 1692 and the personid is 54693
# the tournament id is 1692 and the personid is 59973
# the tournament id is 1692 and the personid is 46475
# the tournament id is 1692 and the personid is 29043
# the tournament id is 1692 and the personid is 57157
# the tournament id is 1692 and the personid is 55784
# the tournament id is 1692 and the personid is 51080
# the tournament id is 1692 and the personid is 33406
# the tournament id is 1692 and the personid is 48360
# the tournament id is 1692 and the personid is 53273
# the tournament id is 1692 and the personid is 52746
# the tournament id is 1692 and the personid is 52829
# the tournament id is 1692 and the personid is 52894
# the tournament id is 1692 and the personid is 26802
# the tournament id is 1692 and the personid is 59353
# the tournament id is 1692 and the personid is 46033
# the tournament id is 1692 and the personid is 60691
# the tournament id is 1692 and the personid is 60330
# the tournament id is 1692 and the personid is 59658
# the tournament id is 1692 and the personid is 60685
# the tournament id is 1692 and the personid is 56630
# the tournament id is 1692 and the personid is 59436
# the tournament id is 1692 and the personid is 16059
# the tournament id is 1692 and the personid is 54992
# the tournament id is 1692 and the personid is 44196
# the tournament id is 1692 and the personid is 56594
# the tournament id is 1692 and the personid is 52280
# the tournament id is 1692 and the personid is 60693
# the tournament id is 1692 and the personid is 59348
# the tournament id is 1692 and the personid is 51654
# the tournament id is 1692 and the personid is 54737
# the tournament id is 1692 and the personid is 38829
# the tournament id is 1692 and the personid is 59378
# the tournament id is 1692 and the personid is 52827
# the tournament id is 1692 and the personid is 60680
# the tournament id is 1692 and the personid is 57695
# the tournament id is 1692 and the personid is 51671
# the tournament id is 1692 and the personid is 59643
# the tournament id is 1692 and the personid is 47432
# the tournament id is 1692 and the personid is 38138
# the tournament id is 1692 and the personid is 56625
# the tournament id is 1692 and the personid is 59375
# the tournament id is 1692 and the personid is 60686
# the tournament id is 1692 and the personid is 60003
# the tournament id is 1692 and the personid is 54260
# the tournament id is 1692 and the personid is 45625
# the tournament id is 1692 and the personid is 56593
# the tournament id is 1692 and the personid is 55783
# the tournament id is 1692 and the personid is 60224
# the tournament id is 1692 and the personid is 54681
# the tournament id is 1692 and the personid is 56556
# the tournament id is 1692 and the personid is 42988
# the tournament id is 1692 and the personid is 32333
# the tournament id is 1692 and the personid is 45693
# the tournament id is 1692 and the personid is 56553
# the tournament id is 1692 and the personid is 32657
# the tournament id is 1692 and the personid is 60681
# the tournament id is 1692 and the personid is 49917
# the tournament id is 1692 and the personid is 59395
# the tournament id is 1692 and the personid is 59361
# the tournament id is 1692 and the personid is 48842
# the tournament id is 1692 and the personid is 54944
# the tournament id is 1692 and the personid is 42464
# the tournament id is 1692 and the personid is 60679
# the tournament id is 1692 and the personid is 51330
# the tournament id is 1692 and the personid is 59430
# the tournament id is 1692 and the personid is 52263
# the tournament id is 1692 and the personid is 46038
# the tournament id is 1692 and the personid is 60682
# the tournament id is 1692 and the personid is 59411
# the tournament id is 1693
# the tournament id is 1693 and the personid is 55785
# the tournament id is 1693 and the personid is 60688
# the tournament id is 1693 and the personid is 49046
# the tournament id is 1693 and the personid is 30046
# the tournament id is 1693 and the personid is 28901
# the tournament id is 1693 and the personid is 53380
# the tournament id is 1693 and the personid is 50538
# the tournament id is 1693 and the personid is 55027
# the tournament id is 1693 and the personid is 60275
# the tournament id is 1693 and the personid is 54297
# the tournament id is 1693 and the personid is 51742
# the tournament id is 1693 and the personid is 58720
# the tournament id is 1693 and the personid is 32149
# the tournament id is 1693 and the personid is 60226
# the tournament id is 1693 and the personid is 29071
# the tournament id is 1693 and the personid is 60222
# the tournament id is 1693 and the personid is 54675
# the tournament id is 1693 and the personid is 42461
# the tournament id is 1693 and the personid is 51604
# the tournament id is 1693 and the personid is 60790
# the tournament id is 1693 and the personid is 51362
# the tournament id is 1693 and the personid is 43474
# the tournament id is 1693 and the personid is 60683
# the tournament id is 1693 and the personid is 54679
# the tournament id is 1693 and the personid is 54246
# the tournament id is 1693 and the personid is 59434
# the tournament id is 1693 and the personid is 59373
# the tournament id is 1693 and the personid is 57156
# the tournament id is 1693 and the personid is 60782
# the tournament id is 1693 and the personid is 59480
# the tournament id is 1693 and the personid is 52436
# the tournament id is 1693 and the personid is 59366
# the tournament id is 1693 and the personid is 56563
# the tournament id is 1693 and the personid is 42991
# the tournament id is 1693 and the personid is 51278
# the tournament id is 1693 and the personid is 50593
# the tournament id is 1693 and the personid is 29397
# the tournament id is 1693 and the personid is 43088
# the tournament id is 1693 and the personid is 49125
# the tournament id is 1693 and the personid is 60692
# the tournament id is 1693 and the personid is 32150
# the tournament id is 1693 and the personid is 56571
# the tournament id is 1693 and the personid is 30897
# the tournament id is 1693 and the personid is 39111
# the tournament id is 1693 and the personid is 50766
# the tournament id is 1693 and the personid is 52216
# the tournament id is 1693 and the personid is 60786
# the tournament id is 1693 and the personid is 60684
# the tournament id is 1693 and the personid is 59429
# the tournament id is 1693 and the personid is 59476
# the tournament id is 1693 and the personid is 60783
# the tournament id is 1693 and the personid is 51780
# the tournament id is 1693 and the personid is 52706
# the tournament id is 1693 and the personid is 56569
# the tournament id is 1693 and the personid is 47437
# the tournament id is 1693 and the personid is 59651
# the tournament id is 1693 and the personid is 52800
# the tournament id is 1693 and the personid is 53431
# the tournament id is 1693 and the personid is 47467
# the tournament id is 1693 and the personid is 50790
# the tournament id is 1693 and the personid is 52277
# the tournament id is 1693 and the personid is 43446
# the tournament id is 1693 and the personid is 54261
# the tournament id is 1693 and the personid is 50326
# the tournament id is 1693 and the personid is 60690
# the tournament id is 1693 and the personid is 51118
# the tournament id is 1693 and the personid is 48983
# the tournament id is 1693 and the personid is 46233
# the tournament id is 1693 and the personid is 60225
# the tournament id is 1693 and the personid is 60791
# the tournament id is 1693 and the personid is 55692
# the tournament id is 1693 and the personid is 59990
# the tournament id is 1693 and the personid is 60689
# the tournament id is 1693 and the personid is 51788
# the tournament id is 1693 and the personid is 51552
# the tournament id is 1693 and the personid is 54283
# the tournament id is 1693 and the personid is 60228
# the tournament id is 1693 and the personid is 55641
# the tournament id is 1693 and the personid is 28585
# the tournament id is 1693 and the personid is 59384
# the tournament id is 1693 and the personid is 48980
# the tournament id is 1693 and the personid is 51613
# the tournament id is 1693 and the personid is 50319
# the tournament id is 1693 and the personid is 59649
# the tournament id is 1693 and the personid is 59479
# the tournament id is 1693 and the personid is 43174
# the tournament id is 1693 and the personid is 52350
# the tournament id is 1693 and the personid is 56577
# the tournament id is 1693 and the personid is 59360
# the tournament id is 1693 and the personid is 60847
# the tournament id is 1693 and the personid is 45717
# the tournament id is 1693 and the personid is 51523
# the tournament id is 1693 and the personid is 55841
# the tournament id is 1693 and the personid is 48721
# the tournament id is 1693 and the personid is 59410
# the tournament id is 1693 and the personid is 49628
# the tournament id is 1693 and the personid is 53267
# the tournament id is 1693 and the personid is 28965
# the tournament id is 1693 and the personid is 54282
# the tournament id is 1693 and the personid is 57295
# the tournament id is 1693 and the personid is 56609
# the tournament id is 1693 and the personid is 53295
# the tournament id is 1693 and the personid is 60787
# the tournament id is 1693 and the personid is 45506
# the tournament id is 1693 and the personid is 52291
# the tournament id is 1693 and the personid is 56598
# the tournament id is 1693 and the personid is 52312
# the tournament id is 1693 and the personid is 52384
# the tournament id is 1693 and the personid is 48658
# the tournament id is 1693 and the personid is 59424
# the tournament id is 1693 and the personid is 40061
# the tournament id is 1693 and the personid is 60694
# the tournament id is 1693 and the personid is 48058
# the tournament id is 1693 and the personid is 60687
# the tournament id is 1693 and the personid is 51662
# the tournament id is 1693 and the personid is 59793
# the tournament id is 1693 and the personid is 59354
# the tournament id is 1693 and the personid is 54287
# the tournament id is 1693 and the personid is 39659
# the tournament id is 1693 and the personid is 44109
# the tournament id is 1693 and the personid is 34168
# the tournament id is 1693 and the personid is 54989
# the tournament id is 1693 and the personid is 53333
# the tournament id is 1693 and the personid is 59426
# the tournament id is 1693 and the personid is 60785
# the tournament id is 1693 and the personid is 60239
# the tournament id is 1693 and the personid is 60223
# the tournament id is 1693 and the personid is 59646
# the tournament id is 1693 and the personid is 60792
# the tournament id is 1693 and the personid is 59973
# the tournament id is 1693 and the personid is 55784
# the tournament id is 1693 and the personid is 46475
# the tournament id is 1693 and the personid is 33406
# the tournament id is 1693 and the personid is 51080
# the tournament id is 1693 and the personid is 53273
# the tournament id is 1693 and the personid is 48360
# the tournament id is 1693 and the personid is 59403
# the tournament id is 1693 and the personid is 52829
# the tournament id is 1693 and the personid is 52894
# the tournament id is 1693 and the personid is 26802
# the tournament id is 1693 and the personid is 46033
# the tournament id is 1693 and the personid is 59353
# the tournament id is 1693 and the personid is 46458
# the tournament id is 1693 and the personid is 60784
# the tournament id is 1693 and the personid is 60691
# the tournament id is 1693 and the personid is 60330
# the tournament id is 1693 and the personid is 59658
# the tournament id is 1693 and the personid is 56630
# the tournament id is 1693 and the personid is 60685
# the tournament id is 1693 and the personid is 54992
# the tournament id is 1693 and the personid is 44196
# the tournament id is 1693 and the personid is 56594
# the tournament id is 1693 and the personid is 52280
# the tournament id is 1693 and the personid is 60693
# the tournament id is 1693 and the personid is 59348
# the tournament id is 1693 and the personid is 51654
# the tournament id is 1693 and the personid is 54737
# the tournament id is 1693 and the personid is 38829
# the tournament id is 1693 and the personid is 60788
# the tournament id is 1693 and the personid is 59378
# the tournament id is 1693 and the personid is 52827
# the tournament id is 1693 and the personid is 60680
# the tournament id is 1693 and the personid is 57695
# the tournament id is 1693 and the personid is 51671
# the tournament id is 1693 and the personid is 59643
# the tournament id is 1693 and the personid is 38138
# the tournament id is 1693 and the personid is 47432
# the tournament id is 1693 and the personid is 56625
# the tournament id is 1693 and the personid is 60686
# the tournament id is 1693 and the personid is 60003
# the tournament id is 1693 and the personid is 45625
# the tournament id is 1693 and the personid is 54260
# the tournament id is 1693 and the personid is 56593
# the tournament id is 1693 and the personid is 55783
# the tournament id is 1693 and the personid is 56581
# the tournament id is 1693 and the personid is 54681
# the tournament id is 1693 and the personid is 56556
# the tournament id is 1693 and the personid is 42988
# the tournament id is 1693 and the personid is 32333
# the tournament id is 1693 and the personid is 32657
# the tournament id is 1693 and the personid is 56553
# the tournament id is 1693 and the personid is 60681
# the tournament id is 1693 and the personid is 59395
# the tournament id is 1693 and the personid is 59794
# the tournament id is 1693 and the personid is 48842
# the tournament id is 1693 and the personid is 54944
# the tournament id is 1693 and the personid is 42464
# the tournament id is 1693 and the personid is 60679
# the tournament id is 1693 and the personid is 46038
# the tournament id is 1693 and the personid is 51330
# the tournament id is 1693 and the personid is 59430
# the tournament id is 1693 and the personid is 59411
