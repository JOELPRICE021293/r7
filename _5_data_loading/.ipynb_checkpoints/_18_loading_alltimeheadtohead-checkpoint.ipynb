# %% [markdown]
# Author: Marijse
#
# Question to Pierre: The 'all time team match record vs opponent' seems empty? Similar view arises for the 'All time team match record' table.
#
# Table URL: http://webservices.irb.com/EventInformation.asmx/AllTimeHeadtoHead
#
# Required fiels:
# - UID
# - EventID
# - Team1ID
# - Team2ID

# %%
# import the necessary packages
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
import glob
from datetime import datetime
import urllib.request
import requests
import io

# %%
# Set up the database connection wiht Psycopg2
db = psycopg2.connect(dbname='Rugby', user='postgres', host='localhost', password='password')
cursor=db.cursor()

# Set up a database connection using sqlalchemy
engine = create_engine('postgres://postgres:password@localhost:5432/Rugby')

# %%
# Define variables

# Define the input and output strings
input_string = '../_4_data_extracts/squad/'
output_strig = '../_6_data_clean/'

# Define schemas
schema1 = '_0_original_data'
schema2 = '_1_data_views'

# %%
cursor.execute("CREATE SCHEMA IF NOT EXISTS " + schema1)
cursor.execute("CREATE SCHEMA IF NOT EXISTS " + schema2)
db.commit()

# %% [markdown]
# ### Reading Match Fixtures into datafrmae

# %%
# Step 2: we run the function
def xml2df(xml_data):
    root = ET.XML(xml_data) # element tree
    all_records = []
    for i, child in enumerate(root):
        record = {}
        for subchild in child:
            record[subchild.tag] = subchild.text
            all_records.append(record)
    return pd.DataFrame(all_records)

# %%
# List all event id's of the past two years
eventid = pd.read_sql_query('select eventid from _0_original_data.tournament_id_dictionary',db)
eventid_list = list(eventid.eventid.unique())

# %%
# Define an empty dataframe to append the different xml files to
all_time_head_to_head = pd.DataFrame()

#eventid_list = ['1611']

for k in eventid_list:
    
    print('the tournament id is ' + k)
    
    teamid = pd.read_sql_query("select team1id from _0_original_data.match_fixtures where tournament_id = '"+k+"'",db)
    teamid_list = list(teamid.team1id.unique())
    
    for n in teamid_list:
    
        opponentid = pd.read_sql_query("select team2id from _0_original_data.match_fixtures \
                                         where tournament_id = '"+k+"' and team1id = '"+n+"'",db)
        opponentid_list = list(opponentid.team2id.unique())
        
        print('the team1id is ' +n)
    
        for m in opponentid_list:
            
            print('the team2id is ' + m)
                            
            url = 'http://webservices.irb.com/EventInformation.asmx/AllTimeHeadtoHead?uid=e9656db8-ffb5-4115-ac0b-cbd5688e6648&eventid='+k+'&team1id='+n+'&team2id='+m
            response = urllib.request.urlopen(url)
            data = response.read()      
            text = data.decode('utf-8') 
        
            # Create a df which equals the text object
            df = xml2df(text)
            
            # Skip all empty Event ID's
            if df.empty == True:
                continue
            else:
                pass
        
            print('we got this far')

            # Extract the tournament id from the file name
            tournament_id =  k
            team1id = m
            team2id = n
        
            # Set a column equal to the file name
            df['tournament_id'] = tournament_id
            df['team1id'] = team1id
            df['team2id'] = team2id

            # Clean the column headers 
            dict_columns={}
            for x in (df.columns.values):
                dict_columns[x] = x.lower().replace('{http://webservices.irb.com/}','')
            df_clean = df.rename(columns=dict_columns)
    
            # remove duplicates from the data
            df_clean = df_clean.drop_duplicates(['tournament_id','team1id','team2id'], keep='first')
        
            # Append each individual dataframe to the full_fixtures df
            frames =(all_time_head_to_head,df_clean)
            all_time_head_to_head = pd.concat(frames)
# Out:
# the tournament id is 1382
# the team1id is 2416
# the team2id is 2421
# we got this far
# the team2id is 3903
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2413
# the team2id is 3924
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2421
# we got this far
# the team1id is 2409
# the team2id is 2422
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2421
# we got this far
# the team1id is 2418
# the team2id is 2423
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2419
# the team2id is 3903
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 3924
# we got this far
# the team1id is 2410
# the team2id is 3892
# we got this far
# the team2id is 3924
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2414
# the team2id is 2415
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2420
# the team2id is 3895
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2421
# the team2id is 2419
# we got this far
# the team2id is 3903
# we got this far
# the team1id is 3924
# the team2id is 3892
# we got this far
# the team2id is 3903
# we got this far
# the team1id is 2422
# the team2id is 2415
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 3924
# we got this far
# the team1id is 2423
# the team2id is 3895
# we got this far
# the team1id is 2415
# the team2id is 2423
# we got this far
# the tournament id is 1386
# the team1id is 2413
# the team2id is 2423
# we got this far
# the team2id is 3904
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2410
# the team2id is 3904
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 3904
# the team2id is 2423
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 3892
# the team2id is 2408
# we got this far
# the team2id is 3924
# we got this far
# the team2id is 3903
# we got this far
# the team1id is 2416
# the team2id is 3924
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 3924
# the team2id is 2408
# we got this far
# the team1id is 2414
# the team2id is 2421
# we got this far
# the team1id is 3903
# the team2id is 2409
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2421
# we got this far
# the team1id is 2409
# the team2id is 2421
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2418
# the team2id is 3919
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 3903
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2420
# the team2id is 2415
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 3919
# the team2id is 2415
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2421
# we got this far
# the team1id is 2408
# the team2id is 2414
# we got this far
# the team2id is 2421
# we got this far
# the team1id is 2421
# the team2id is 3924
# we got this far
# the tournament id is 1388
# the team1id is 3919
# the team2id is 3908
# we got this far
# the team2id is 3913
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2416
# the team2id is 3913
# we got this far
# the team2id is 3908
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 3913
# the team2id is 3908
# we got this far
# the team2id is 3907
# we got this far
# the team2id is 3893
# we got this far
# the team1id is 2413
# the team2id is 2410
# we got this far
# the team2id is 3907
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2414
# the team2id is 3907
# we got this far
# the team2id is 3908
# we got this far
# the team1id is 2410
# the team2id is 2414
# we got this far
# the team2id is 3907
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2409
# the team2id is 3887
# we got this far
# the team2id is 3893
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2420
# the team2id is 3893
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 3887
# the team2id is 3893
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 3886
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2408
# the team2id is 3886
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2418
# the team2id is 2422
# we got this far
# the team2id is 3886
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2422
# the team2id is 3886
# we got this far
# the team1id is 3893
# the team2id is 2422
# we got this far
# the team2id is 2414
# we got this far
# the tournament id is 1387
# the team1id is 3893
# the team2id is 3919
# we got this far
# the team2id is 3908
# we got this far
# the team2id is 3887
# we got this far
# the team1id is 2410
# the team2id is 3919
# we got this far
# the team2id is 3893
# we got this far
# the team1id is 2413
# the team2id is 3893
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2422
# the team2id is 3908
# we got this far
# the team2id is 3919
# we got this far
# the team1id is 2414
# the team2id is 2422
# we got this far
# the team2id is 3908
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2416
# the team2id is 3908
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 3913
# the team2id is 3886
# we got this far
# the team2id is 3907
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2420
# the team2id is 3886
# we got this far
# the team2id is 3913
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2408
# the team2id is 3913
# we got this far
# the team2id is 3886
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 3887
# the team2id is 3907
# we got this far
# the team2id is 3886
# we got this far
# the team2id is 3913
# we got this far
# the team1id is 2409
# the team2id is 3887
# we got this far
# the team2id is 3907
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2418
# the team2id is 3907
# we got this far
# the team2id is 3887
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2408
# we got this far
# the tournament id is 1389
# the team1id is 2413
# the team2id is 2422
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 3919
# the team2id is 2414
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2414
# the team2id is 2422
# we got this far
# the team2id is 3890
# we got this far
# the team2id is 2421
# we got this far
# the team1id is 2418
# the team2id is 2423
# we got this far
# the team2id is 2421
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2410
# the team2id is 2421
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 2423
# the team2id is 2421
# we got this far
# the team2id is 3920
# we got this far
# the team2id is 3906
# we got this far
# the team1id is 2409
# the team2id is 2411
# we got this far
# the team2id is 3920
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2420
# the team2id is 3920
# we got this far
# the team2id is 2411
# we got this far
# the team2id is 3919
# we got this far
# the team1id is 2411
# the team2id is 3920
# we got this far
# the team1id is 3890
# the team2id is 2416
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2408
# the team2id is 3906
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2416
# the team2id is 2408
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 3919
# we got this far
# the team1id is 2421
# the team2id is 2411
# we got this far
# the team2id is 3906
# we got this far
# the team1id is 3906
# the team2id is 2422
# we got this far
# the tournament id is 1383
# the team1id is 2410
# the team2id is 3895
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2418
# the team2id is 3906
# we got this far
# the team2id is 3895
# we got this far
# the team1id is 3906
# the team2id is 3895
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 3919
# we got this far
# the team1id is 2408
# the team2id is 3919
# we got this far
# the team2id is 2411
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2413
# the team2id is 2411
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 3919
# the team2id is 2411
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 2414
# the team2id is 2421
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 2416
# the team2id is 2423
# we got this far
# the team2id is 2421
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2421
# the team2id is 2423
# we got this far
# the team2id is 2411
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 3906
# we got this far
# the team1id is 2420
# the team2id is 3888
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2409
# the team2id is 2422
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2422
# the team2id is 3888
# we got this far
# the team1id is 3895
# the team2id is 2422
# we got this far
# the tournament id is 1380
# the team1id is 2413
# the team2id is 3888
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2422
# the team2id is 3898
# we got this far
# the team2id is 3888
# we got this far
# the team1id is 2416
# the team2id is 3912
# we got this far
# the team2id is 3897
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 3897
# the team2id is 2423
# we got this far
# the team2id is 3912
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2409
# the team2id is 3915
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 3895
# the team2id is 2419
# we got this far
# the team2id is 3915
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 3890
# we got this far
# the team1id is 2418
# the team2id is 3914
# we got this far
# the team2id is 3918
# we got this far
# the team1id is 2412
# the team2id is 3918
# we got this far
# the team2id is 3914
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2420
# the team2id is 3889
# we got this far
# the team2id is 3890
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2414
# the team2id is 3890
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2419
# we got this far
# the team1id is 2410
# the team2id is 3900
# we got this far
# the team2id is 3896
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2408
# the team2id is 3896
# we got this far
# the team2id is 3900
# we got this far
# the team1id is 3898
# the team2id is 3888
# we got this far
# the team1id is 2423
# the team2id is 3912
# we got this far
# the team1id is 2419
# the team2id is 3915
# we got this far
# the team1id is 3914
# the team2id is 3918
# we got this far
# the team1id is 3890
# the team2id is 3889
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 3896
# the team2id is 3900
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 3915
# we got this far
# the team2id is 3888
# we got this far
# the team1id is 3915
# the team2id is 3900
# we got this far
# the team1id is 3918
# the team2id is 3912
# we got this far
# the team2id is 3888
# we got this far
# the team1id is 3888
# the team2id is 3914
# we got this far
# the tournament id is 1381
# the team1id is 2413
# the team2id is 3914
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 3906
# the team2id is 3895
# we got this far
# the team2id is 3914
# we got this far
# the team1id is 3895
# the team2id is 3914
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2416
# the team2id is 3889
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 3906
# we got this far
# the team1id is 2414
# the team2id is 2422
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 2422
# the team2id is 3889
# we got this far
# the team2id is 3914
# we got this far
# the team1id is 2409
# the team2id is 3912
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2410
# the team2id is 3898
# we got this far
# the team2id is 3912
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 3898
# the team2id is 3912
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2418
# the team2id is 3900
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 3912
# we got this far
# the team2id is 3898
# we got this far
# the team1id is 2423
# the team2id is 2420
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 3906
# we got this far
# the team1id is 2420
# the team2id is 3900
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 3906
# we got this far
# the tournament id is 1385
# the team1id is 2413
# the team2id is 2423
# we got this far
# the team2id is 3896
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2414
# the team2id is 3896
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 3896
# the team2id is 2423
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2416
# the team2id is 3903
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2408
# the team2id is 2422
# we got this far
# the team2id is 3903
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 3903
# the team2id is 2422
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 3891
# we got this far
# the team1id is 2409
# the team2id is 3891
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2410
# the team2id is 2419
# we got this far
# the team2id is 3891
# we got this far
# the team1id is 3891
# the team2id is 2419
# we got this far
# the team2id is 3892
# we got this far
# the team1id is 2418
# the team2id is 3892
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 3896
# we got this far
# the team2id is 3903
# we got this far
# the team1id is 2420
# the team2id is 2412
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2412
# the team2id is 2418
# we got this far
# the team2id is 3892
# we got this far
# the tournament id is 1395
# the team1id is 2416
# the team2id is 3910
# we got this far
# the team2id is 3904
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2414
# the team2id is 3904
# we got this far
# the team2id is 3910
# we got this far
# the team1id is 3910
# the team2id is 3904
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2413
# the team2id is 3921
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2410
# the team2id is 2415
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 3921
# the team2id is 2415
# we got this far
# the team2id is 3904
# we got this far
# the team2id is 3903
# we got this far
# the team1id is 2409
# the team2id is 2412
# we got this far
# the team2id is 3924
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2408
# the team2id is 3924
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2412
# the team2id is 3924
# we got this far
# the team1id is 2420
# the team2id is 3892
# we got this far
# the team2id is 3903
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2418
# the team2id is 3903
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 3892
# the team2id is 3903
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 3903
# the team2id is 3924
# we got this far
# the tournament id is 1396
# the team1id is 2416
# the team2id is 3892
# we got this far
# the team2id is 3918
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2412
# the team2id is 3918
# we got this far
# the team2id is 3892
# we got this far
# the team1id is 2413
# the team2id is 3896
# we got this far
# the team2id is 3903
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2408
# the team2id is 3903
# we got this far
# the team2id is 3896
# we got this far
# the team2id is 3924
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2409
# the team2id is 3895
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2418
# the team2id is 2415
# we got this far
# the team2id is 3895
# we got this far
# the team1id is 2420
# the team2id is 3921
# we got this far
# the team2id is 3924
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2410
# the team2id is 3924
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2415
# we got this far
# the team1id is 3892
# the team2id is 3918
# we got this far
# the team2id is 3903
# we got this far
# the team1id is 3896
# the team2id is 3903
# we got this far
# the team2id is 3918
# we got this far
# the team1id is 3895
# the team2id is 2415
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 3921
# the team2id is 3924
# we got this far
# the team2id is 3896
# we got this far
# the team1id is 3924
# the team2id is 2418
# we got this far
# the team1id is 3903
# the team2id is 2410
# we got this far
# the team2id is 3896
# we got this far
# the tournament id is 1397
# the team1id is 2416
# the team2id is 2421
# we got this far
# the team2id is 2417
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2410
# the team2id is 2417
# we got this far
# the team2id is 2421
# we got this far
# the team1id is 2421
# the team2id is 2417
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2422
# the team2id is 2413
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2412
# the team2id is 3888
# we got this far
# the team2id is 2417
# we got this far
# the team1id is 2413
# the team2id is 3888
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2416
# we got this far
# the team2id is 2411
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2409
# the team2id is 2411
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2420
# the team2id is 2423
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2411
# the team2id is 2420
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2408
# the team2id is 3921
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2418
# the team2id is 3906
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 3921
# the team2id is 3906
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 3888
# the team2id is 2423
# we got this far
# the team1id is 3906
# the team2id is 2417
# we got this far
# the team1id is 2423
# the team2id is 3906
# we got this far
# the tournament id is 1390
# the team1id is 2413
# the team2id is 3922
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2409
# the team2id is 3914
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 3910
# we got this far
# the team1id is 2416
# the team2id is 3918
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2418
# the team2id is 3912
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2408
# the team2id is 3900
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2420
# the team2id is 3915
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 3921
# the team2id is 3911
# we got this far
# the team2id is 3922
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 3910
# the team2id is 3898
# we got this far
# the team2id is 3914
# we got this far
# the team1id is 2414
# the team2id is 3895
# we got this far
# the team2id is 3918
# we got this far
# the team1id is 2412
# the team2id is 2423
# we got this far
# the team2id is 3912
# we got this far
# the team1id is 2410
# the team2id is 3888
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2422
# the team2id is 3889
# we got this far
# the team2id is 3915
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 3910
# we got this far
# the team1id is 3911
# the team2id is 3922
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 3898
# the team2id is 3914
# we got this far
# the team1id is 3895
# the team2id is 3918
# we got this far
# the team1id is 2423
# the team2id is 3912
# we got this far
# the team2id is 3910
# we got this far
# the team1id is 3888
# the team2id is 3900
# we got this far
# the team1id is 3889
# the team2id is 3915
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 3922
# we got this far
# the team1id is 3922
# the team2id is 3915
# we got this far
# the team2id is 3895
# we got this far
# the team1id is 3918
# the team2id is 3914
# we got this far
# the team2id is 3895
# we got this far
# the team1id is 3912
# the team2id is 3895
# we got this far
# the tournament id is 1398
# the team1id is 2413
# the team2id is 3889
# we got this far
# the team2id is 3900
# we got this far
# the team1id is 2420
# the team2id is 3900
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 3889
# the team2id is 3900
# we got this far
# the team1id is 2409
# the team2id is 3921
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2412
# the team2id is 3888
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 3921
# the team2id is 3888
# we got this far
# the team2id is 3900
# we got this far
# the team1id is 2416
# the team2id is 2423
# we got this far
# the team2id is 3914
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2408
# the team2id is 3914
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 2423
# the team2id is 3914
# we got this far
# the team1id is 3898
# the team2id is 2418
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2410
# the team2id is 3895
# we got this far
# the team2id is 3914
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2418
# the team2id is 3895
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 3888
# the team2id is 3889
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 3895
# the team2id is 2423
# we got this far
# the team2id is 3921
# we got this far
# the tournament id is 1394
# the team1id is 2416
# the team2id is 3921
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2412
# the team2id is 3900
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 3898
# we got this far
# the team1id is 3921
# the team2id is 2412
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2409
# the team2id is 2414
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2410
# the team2id is 3889
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 3900
# we got this far
# the team1id is 2414
# the team2id is 3889
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2413
# the team2id is 3898
# we got this far
# the team2id is 3915
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2408
# the team2id is 3915
# we got this far
# the team2id is 3898
# we got this far
# the team1id is 3898
# the team2id is 3915
# we got this far
# the team2id is 3912
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2418
# the team2id is 2423
# we got this far
# the team2id is 3912
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2420
# the team2id is 3912
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2423
# the team2id is 3912
# we got this far
# the team2id is 3915
# we got this far
# the tournament id is 1393
# the team1id is 2416
# the team2id is 3898
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2420
# the team2id is 3889
# we got this far
# the team2id is 3898
# we got this far
# the team1id is 3898
# the team2id is 3889
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2409
# the team2id is 2423
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2412
# the team2id is 3900
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2423
# the team2id is 3900
# we got this far
# the team2id is 3889
# we got this far
# the team1id is 2413
# the team2id is 2414
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2410
# the team2id is 3895
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2414
# the team2id is 3895
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2418
# the team2id is 2422
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2408
# the team2id is 3921
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 3895
# we got this far
# the team1id is 2422
# the team2id is 3921
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 3921
# the team2id is 2420
# we got this far
# the tournament id is 1391
# the team1id is 2413
# the team2id is 3910
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2420
# the team2id is 2419
# we got this far
# the team2id is 3910
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2409
# the team2id is 2414
# we got this far
# the team2id is 3913
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2408
# the team2id is 3913
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2416
# the team2id is 3892
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2410
# the team2id is 3911
# we got this far
# the team2id is 3892
# we got this far
# the team1id is 2418
# the team2id is 3921
# we got this far
# the team2id is 3922
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2412
# the team2id is 3922
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 3910
# the team2id is 2419
# we got this far
# the team1id is 2414
# the team2id is 3913
# we got this far
# the team2id is 3892
# we got this far
# the team1id is 3892
# the team2id is 3911
# we got this far
# the team1id is 3921
# the team2id is 3922
# we got this far
# the team2id is 3910
# we got this far
# the team2id is 2419
# we got this far
# the team1id is 3911
# the team2id is 3913
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2419
# the team2id is 3922
# we got this far
# the team2id is 3892
# we got this far
# the tournament id is 1392
# the team1id is 2418
# the team2id is 2414
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 3892
# we got this far
# the team1id is 2420
# the team2id is 3911
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2410
# the team2id is 2419
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 3922
# we got this far
# the team1id is 2409
# the team2id is 3921
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2413
# the team2id is 3892
# we got this far
# the team2id is 3913
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2412
# the team2id is 3913
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2416
# the team2id is 3910
# we got this far
# the team2id is 3922
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2408
# the team2id is 3922
# we got this far
# the team2id is 3910
# we got this far
# the team1id is 2414
# the team2id is 3911
# we got this far
# the team1id is 3892
# the team2id is 3913
# we got this far
# the team1id is 3910
# the team2id is 3922
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 3913
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 3921
# the team2id is 2419
# we got this far
# the team2id is 3892
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 3911
# the team2id is 3913
# we got this far
# the tournament id is 1409
# the team1id is 2420
# the team2id is 2414
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2412
# the team2id is 3919
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2416
# the team2id is 2410
# we got this far
# the team2id is 3907
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 3921
# the team2id is 3907
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2409
# the team2id is 2422
# we got this far
# the team2id is 3886
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2408
# the team2id is 3886
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2418
# the team2id is 3887
# we got this far
# the team2id is 3922
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2413
# the team2id is 3922
# we got this far
# the team2id is 3887
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2414
# the team2id is 3919
# we got this far
# the team2id is 3887
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2410
# the team2id is 3907
# we got this far
# the team2id is 3886
# we got this far
# the team2id is 3922
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2422
# the team2id is 3886
# we got this far
# the team2id is 3907
# we got this far
# the team1id is 3887
# the team2id is 3922
# we got this far
# the team2id is 3907
# we got this far
# the team1id is 3922
# the team2id is 3919
# we got this far
# the team1id is 3886
# the team2id is 3919
# we got this far
# the team1id is 3919
# the team2id is 3887
# we got this far
# the tournament id is 1407
# the team1id is 2418
# the team2id is 2422
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 3921
# the team2id is 3919
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2420
# the team2id is 2410
# we got this far
# the team2id is 3886
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2413
# the team2id is 3886
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2416
# the team2id is 2414
# we got this far
# the team2id is 3922
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2408
# the team2id is 3922
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2409
# the team2id is 3887
# we got this far
# the team2id is 3907
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2412
# the team2id is 3907
# we got this far
# the team2id is 3887
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2422
# the team2id is 3919
# we got this far
# the team2id is 3886
# we got this far
# the team1id is 2410
# the team2id is 3886
# we got this far
# the team2id is 3919
# we got this far
# the team2id is 3922
# we got this far
# the team1id is 2414
# the team2id is 3922
# we got this far
# the team2id is 3887
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 3887
# the team2id is 3907
# we got this far
# the team2id is 3886
# we got this far
# the team1id is 3922
# the team2id is 3907
# we got this far
# the team1id is 3919
# the team2id is 3907
# we got this far
# the tournament id is 1405
# the team1id is 2413
# the team2id is 2411
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2408
# the team2id is 3888
# we got this far
# the team2id is 2411
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2420
# the team2id is 2410
# we got this far
# the team2id is 2421
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2412
# the team2id is 2421
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2416
# the team2id is 2414
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2418
# the team2id is 2423
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2409
# the team2id is 2422
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 3921
# the team2id is 3906
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2411
# the team2id is 3888
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2410
# the team2id is 2421
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2414
# the team2id is 2423
# we got this far
# the team1id is 2422
# the team2id is 3906
# we got this far
# the team1id is 2423
# the team2id is 3888
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2411
# we got this far
# the team1id is 3906
# the team2id is 2421
# we got this far
# the team2id is 2411
# we got this far
# the team1id is 3888
# the team2id is 2410
# we got this far
# the team1id is 2421
# the team2id is 2414
# we got this far
# the tournament id is 1406
# the team1id is 2408
# the team2id is 2423
# we got this far
# the team2id is 2411
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2409
# the team2id is 2411
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 3921
# the team2id is 2421
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2413
# the team2id is 2410
# we got this far
# the team2id is 2421
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2418
# the team2id is 3888
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2420
# the team2id is 2414
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2412
# the team2id is 3906
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2416
# the team2id is 2422
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2411
# the team2id is 2423
# we got this far
# the team2id is 3906
# we got this far
# the team1id is 2410
# the team2id is 2421
# we got this far
# the team2id is 3906
# we got this far
# the team1id is 2414
# the team2id is 3888
# we got this far
# the team2id is 2411
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2422
# the team2id is 3906
# we got this far
# the team2id is 2421
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2423
# the team2id is 3888
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2421
# the team2id is 2411
# we got this far
# the team1id is 3888
# the team2id is 3906
# we got this far
# the tournament id is 1410
# the team1id is 2416
# the team2id is 3898
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2408
# the team2id is 2423
# we got this far
# the team2id is 3898
# we got this far
# the team1id is 2418
# the team2id is 2410
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2412
# the team2id is 3895
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2409
# the team2id is 2414
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2413
# the team2id is 3889
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2420
# the team2id is 2422
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 3921
# the team2id is 3888
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 3898
# the team2id is 2423
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2410
# the team2id is 3895
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2414
# the team2id is 3889
# we got this far
# the team2id is 3895
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2422
# the team2id is 3888
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 3888
# the team2id is 3895
# we got this far
# the team1id is 3889
# the team2id is 2423
# we got this far
# the team1id is 3895
# the team2id is 2423
# we got this far
# the tournament id is 1400
# the team1id is 2416
# the team2id is 3914
# we got this far
# the team2id is 3910
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2420
# the team2id is 3889
# we got this far
# the team2id is 3906
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2419
# we got this far
# the team1id is 2418
# the team2id is 3895
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2409
# the team2id is 3903
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2413
# the team2id is 3912
# we got this far
# the team2id is 3888
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2408
# the team2id is 3915
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2419
# the team2id is 3910
# we got this far
# the team2id is 3914
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2410
# the team2id is 3906
# we got this far
# the team2id is 3889
# we got this far
# the team1id is 2422
# the team2id is 3911
# we got this far
# the team2id is 3895
# we got this far
# the team1id is 2414
# the team2id is 3898
# we got this far
# the team2id is 3903
# we got this far
# the team1id is 3921
# the team2id is 3888
# we got this far
# the team2id is 3912
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2412
# the team2id is 2423
# we got this far
# the team2id is 3915
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 3910
# the team2id is 3914
# we got this far
# the team2id is 2419
# we got this far
# the team1id is 3906
# the team2id is 3889
# we got this far
# the team1id is 3911
# the team2id is 3895
# we got this far
# the team2id is 3889
# we got this far
# the team1id is 3898
# the team2id is 3903
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 3888
# the team2id is 3912
# we got this far
# the team1id is 2423
# the team2id is 3915
# we got this far
# the team2id is 3912
# we got this far
# the team1id is 3903
# the team2id is 3914
# we got this far
# the team2id is 3888
# we got this far
# the team1id is 3915
# the team2id is 3888
# we got this far
# the team1id is 3895
# the team2id is 2422
# we got this far
# the team1id is 3912
# the team2id is 3889
# we got this far
# the team1id is 3889
# the team2id is 3903
# we got this far
# the tournament id is 1408
# the team1id is 2412
# the team2id is 2410
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2408
# the team2id is 3889
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2420
# the team2id is 2419
# we got this far
# the team2id is 3915
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 3921
# the team2id is 3915
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 3912
# we got this far
# the team1id is 2413
# the team2id is 3898
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2409
# the team2id is 3900
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2416
# the team2id is 2423
# we got this far
# the team2id is 3912
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2418
# the team2id is 3912
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2410
# the team2id is 3889
# we got this far
# the team2id is 3915
# we got this far
# the team1id is 2419
# the team2id is 3915
# we got this far
# the team1id is 3898
# the team2id is 3900
# we got this far
# the team2id is 3915
# we got this far
# the team2id is 3889
# we got this far
# the team1id is 2423
# the team2id is 3912
# we got this far
# the team2id is 3898
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 3900
# the team2id is 3912
# we got this far
# the team1id is 3889
# the team2id is 3900
# we got this far
# the tournament id is 1403
# the team1id is 2413
# the team2id is 2419
# we got this far
# the team2id is 3912
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2418
# the team2id is 3912
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2416
# the team2id is 2410
# we got this far
# the team2id is 3900
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 3921
# the team2id is 3900
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2420
# the team2id is 3898
# we got this far
# the team2id is 3889
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 2408
# the team2id is 3889
# we got this far
# ...
# the team2id is 2418
# we got this far
# the tournament id is 1721
# the team1id is 3974
# the team2id is 3967
# we got this far
# the team2id is 3935
# we got this far
# the team1id is 3929
# the team2id is 3935
# we got this far
# the team2id is 3967
# we got this far
# the team2id is 3974
# we got this far
# the team2id is 3962
# we got this far
# the team2id is 3954
# we got this far
# the team1id is 3936
# the team2id is 3942
# we got this far
# the team2id is 3928
# we got this far
# the team2id is 3974
# we got this far
# the team2id is 3954
# we got this far
# the team1id is 3927
# the team2id is 3928
# we got this far
# the team2id is 3942
# we got this far
# the team2id is 3936
# we got this far
# the team2id is 3937
# we got this far
# the team2id is 3929
# we got this far
# the team1id is 3962
# the team2id is 3937
# we got this far
# the team2id is 3944
# we got this far
# the team2id is 3935
# we got this far
# the team1id is 3954
# the team2id is 3944
# we got this far
# the team2id is 3937
# we got this far
# the team2id is 3962
# we got this far
# the team2id is 3935
# we got this far
# the team1id is 3967
# the team2id is 3935
# we got this far
# the team2id is 3944
# we got this far
# the team1id is 3942
# the team2id is 3928
# we got this far
# the team2id is 3967
# we got this far
# the team1id is 3937
# the team2id is 3944
# we got this far
# the team2id is 3962
# we got this far
# the team2id is 3974
# we got this far
# the team1id is 3928
# the team2id is 3942
# we got this far
# the team2id is 3944
# we got this far
# the tournament id is 1692
# the team1id is 2413
# the team2id is 2418
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2409
# the team2id is 3911
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2416
# the team2id is 3921
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2422
# the team2id is 2408
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2416
# we got this far
# the team2id is 2418
# we got this far
# the team1id is 2420
# the team2id is 2419
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2410
# the team2id is 2423
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2415
# the team2id is 2414
# we got this far
# the team2id is 3913
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2412
# the team2id is 3913
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2418
# the team2id is 3911
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 3921
# the team2id is 2408
# we got this far
# the team2id is 3913
# we got this far
# the team1id is 2419
# the team2id is 2423
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2414
# the team2id is 3913
# we got this far
# the team1id is 3911
# the team2id is 2415
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 2423
# the team2id is 3913
# we got this far
# the team1id is 2408
# the team2id is 2409
# we got this far
# the tournament id is 1693
# the team1id is 2413
# the team2id is 2410
# we got this far
# the team2id is 2423
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2416
# the team2id is 2423
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2419
# we got this far
# the team1id is 2414
# the team2id is 2408
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 2419
# the team2id is 3911
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2422
# the team2id is 3921
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2420
# the team2id is 2415
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2418
# the team2id is 2409
# we got this far
# the team2id is 3913
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2423
# we got this far
# the team1id is 2412
# the team2id is 3913
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2420
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2410
# the team2id is 2423
# we got this far
# the team1id is 2408
# the team2id is 3911
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 3921
# the team2id is 2415
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2409
# the team2id is 3913
# we got this far
# the team2id is 2416
# we got this far
# the team2id is 2420
# we got this far
# the team1id is 2415
# the team2id is 3913
# we got this far
# the team2id is 2413
# we got this far
# the team1id is 3913
# the team2id is 3911
# we got this far
# the team1id is 3911
# the team2id is 2418
# we got this far
# the tournament id is 1722
# the team1id is 3935
# the team2id is 3974
# we got this far
# the team2id is 3953
# we got this far
# the team2id is 3942
# we got this far
# the team1id is 3954
# the team2id is 3953
# we got this far
# the team2id is 3974
# we got this far
# the team2id is 3935
# we got this far
# the team2id is 3962
# we got this far
# the team1id is 3936
# the team2id is 3942
# we got this far
# the team2id is 3967
# we got this far
# the team2id is 3928
# we got this far
# the team1id is 3927
# the team2id is 3967
# we got this far
# the team2id is 3942
# we got this far
# the team2id is 3936
# we got this far
# the team2id is 3974
# we got this far
# the team2id is 3937
# we got this far
# the team1id is 3962
# the team2id is 3937
# we got this far
# the team2id is 3928
# we got this far
# the team1id is 3929
# the team2id is 3928
# we got this far
# the team2id is 3937
# we got this far
# the team2id is 3962
# we got this far
# the team2id is 3935
# we got this far
# the team2id is 3927
# we got this far
# the team2id is 3954
# we got this far
# the team1id is 3974
# the team2id is 3953
# we got this far
# the team2id is 3962
# we got this far
# the team1id is 3942
# the team2id is 3967
# we got this far
# the team2id is 3962
# we got this far
# the team1id is 3937
# the team2id is 3928
# we got this far
# the team2id is 3942
# we got this far
# the team2id is 3954
# we got this far
# the team1id is 3967
# the team2id is 3953
# we got this far
# the team2id is 3936
# we got this far
# the team1id is 3953
# the team2id is 3928
# we got this far
# the tournament id is 1723
# the team1id is 3974
# the team2id is 3942
# we got this far
# the team2id is 3944
# we got this far
# the team2id is 3936
# we got this far
# the team1id is 3954
# the team2id is 3944
# we got this far
# the team2id is 3942
# we got this far
# the team2id is 3974
# we got this far
# the team2id is 3936
# we got this far
# the team1id is 3962
# the team2id is 3935
# we got this far
# the team2id is 3928
# we got this far
# the team2id is 3937
# we got this far
# the team2id is 3936
# we got this far
# the team1id is 3929
# the team2id is 3928
# we got this far
# the team2id is 3935
# we got this far
# the team2id is 3962
# we got this far
# the team2id is 3942
# we got this far
# the team2id is 3927
# we got this far
# the team2id is 3937
# we got this far
# the team1id is 3927
# the team2id is 3967
# we got this far
# the team2id is 3936
# we got this far
# the team2id is 3937
# we got this far
# the team2id is 3974
# we got this far
# the team2id is 3954
# we got this far
# the team1id is 3937
# the team2id is 3936
# we got this far
# the team2id is 3967
# we got this far
# the team2id is 3954
# we got this far
# the team1id is 3942
# the team2id is 3944
# we got this far
# the team2id is 3974
# we got this far
# the team2id is 3962
# we got this far
# the team1id is 3935
# the team2id is 3928
# we got this far
# the team2id is 3944
# we got this far
# the team1id is 3936
# the team2id is 3967
# we got this far
# the team1id is 3928
# the team2id is 3967
# we got this far
# the team2id is 3935
# we got this far
# the team1id is 3967
# the team2id is 3944
# we got this far
# the tournament id is 1809
# the team1id is 3936
# the team2id is 3942
# we got this far
# the team2id is 3967
# we got this far
# the team2id is 3966
# we got this far
# the team1id is 3929
# the team2id is 3967
# we got this far
# the team2id is 3942
# we got this far
# the team2id is 3936
# we got this far
# the team2id is 3937
# we got this far
# the team1id is 3962
# the team2id is 3935
# we got this far
# the team2id is 3944
# we got this far
# the team2id is 3967
# we got this far
# the team2id is 3929
# we got this far
# the team1id is 3927
# the team2id is 3944
# we got this far
# the team2id is 3935
# we got this far
# the team2id is 3962
# we got this far
# the team2id is 3929
# we got this far
# the team1id is 3974
# the team2id is 3937
# we got this far
# the team2id is 3966
# we got this far
# the team2id is 3962
# we got this far
# the team2id is 3927
# we got this far
# the team1id is 3954
# the team2id is 3966
# we got this far
# the team2id is 3937
# we got this far
# the team2id is 3974
# we got this far
# the team2id is 3967
# we got this far
# the team1id is 3942
# the team2id is 3967
# we got this far
# the team2id is 3944
# we got this far
# the team2id is 3966
# we got this far
# the team1id is 3935
# the team2id is 3944
# we got this far
# the team2id is 3937
# we got this far
# the team1id is 3937
# the team2id is 3966
# we got this far
# the team1id is 3944
# the team2id is 3936
# we got this far
# the team1id is 3967
# the team2id is 3935
# we got this far
# the tournament id is 1786
# the team1id is 2422
# the team2id is 2408
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 3921
# we got this far
# the team1id is 2416
# the team2id is 2418
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2409
# the team2id is 3921
# we got this far
# the team2id is 3911
# we got this far
# the team1id is 2413
# the team2id is 3911
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2412
# we got this far
# the team1id is 2410
# the team2id is 2415
# we got this far
# the team2id is 2745
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2414
# we got this far
# the team1id is 2420
# the team2id is 2745
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2419
# the team2id is 2414
# we got this far
# the team2id is 3913
# we got this far
# the team1id is 2412
# the team2id is 3913
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2408
# the team2id is 2418
# we got this far
# the team2id is 2745
# we got this far
# the team2id is 3913
# we got this far
# the team1id is 3921
# the team2id is 3911
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2745
# we got this far
# the team1id is 2415
# the team2id is 2745
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2414
# the team2id is 3913
# we got this far
# the team1id is 3913
# the team2id is 3911
# we got this far
# the team1id is 2745
# the team2id is 3911
# we got this far
# the team1id is 2418
# the team2id is 2419
# we got this far
# the team2id is 2409
# we got this far
# the tournament id is 1787
# the team1id is 2418
# the team2id is 2410
# we got this far
# the team2id is 3921
# we got this far
# the team2id is 3913
# we got this far
# the team1id is 2413
# the team2id is 3921
# we got this far
# the team2id is 2410
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2412
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 2419
# the team2id is 2408
# we got this far
# the team2id is 2745
# we got this far
# the team2id is 3913
# we got this far
# the team1id is 2412
# the team2id is 2745
# we got this far
# the team2id is 2408
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2416
# we got this far
# the team1id is 2409
# the team2id is 3913
# we got this far
# the team2id is 2422
# we got this far
# the team2id is 2745
# we got this far
# the team1id is 2416
# the team2id is 2422
# we got this far
# the team2id is 3913
# we got this far
# the team2id is 2409
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2415
# the team2id is 2414
# we got this far
# the team2id is 3911
# we got this far
# the team2id is 2418
# we got this far
# the team2id is 2419
# we got this far
# the team2id is 2745
# we got this far
# the team1id is 2420
# the team2id is 3911
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2415
# we got this far
# the team2id is 2413
# we got this far
# the team2id is 2416
# we got this far
# the team2id is 2410
# we got this far
# the team1id is 2410
# the team2id is 3921
# we got this far
# the team2id is 2414
# we got this far
# the team2id is 2408
# we got this far
# the team1id is 2408
# the team2id is 2745
# we got this far
# the team1id is 3913
# the team2id is 2422
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2414
# the team2id is 3911
# we got this far
# the team2id is 2422
# we got this far
# the team1id is 3921
# the team2id is 3911
# we got this far
# the team2id is 2409
# we got this far
# the team1id is 2422
# the team2id is 2408
# we got this far
# the team1id is 3911
# the team2id is 2745
# we got this far
# the tournament id is 1788
# the team1id is 2412
# the team2id is 3913
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-13-e88cd11486b4> in <module>()
#      23
#      24             url = 'http://webservices.irb.com/EventInformation.asmx/AllTimeHeadtoHead?uid=e9656db8-ffb5-4115-ac0b-cbd5688e6648&eventid='+k+'&team1id='+n+'&team2id='+m
# ---> 25             response = urllib.request.urlopen(url)
#      26             data = response.read()
#      27             text = data.decode('utf-8')
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 500: Internal Server Error

# %%
all_time_head_to_head.head()
# Out:
#   drawn played team1conversions team1dropgoals team1penalties team1points  \
# 0     0      1                2              0              0          14
# 0     0      1                4              0              0          38
# 0     0      1                7              0              0          54
# 0     0      1                3              0              0          21
# 0     0      1                3              0              0          31
#
#   team1tries team1won team2conversions team2dropgoals team2penalties  \
# 0          2        1                0              0              0
# 0          6        1                0              0              0
# 0          8        1                0              0              0
# 0          3        1                2              0              0
# 0          5        1                0              0              0
#
#   team2points team2tries team2won tournament_id team1id team2id
# 0           0          0        0          1382    2421    2416
# 0           0          0        0          1382    3903    2416
# 0           0          0        0          1382    2419    2416
# 0          19          3        0          1382    2410    2416
# 0           0          0        0          1382    2420    2416

# %%
# The final table includes 20 tournaments and has 2680 records associated with 8 methods over the 20 different tournaments. 
all_time_head_to_head.tournament_id.nunique()
all_time_head_to_head.team1id.nunique()
len(all_time_head_to_head)
# Out:
# 7834

# %%
# Extract to CSV
all_time_head_to_head.to_csv('../_6_data_clean/all_time_head_to_head.csv')

# %%
# Extract to SQL
table_name = 'all_time_head_to_head'
all_time_head_to_head.to_sql(schema=schema1, con=engine, if_exists='replace', name=table_name)
db.commit
db.close()
