# %%
import xml.etree.ElementTree as et
import glob
import re
import pandas as pd
from collections import OrderedDict
import sqlalchemy as sa
    
res = []
xml_data_dict = {}

def compute_xml_data(lst,elem, func, level=0):
    func(lst,elem,level)
    for child in elem.getchildren():
        compute_xml_data(lst,child, func, level+1)

def gather_level(lst,elem,level):
    lst.append(('-'*level+elem.tag, elem.text))

xml_files = glob.glob('./*.xml')

for xml_file in xml_files:
    lst = []
    root = et.parse(xml_file)
    compute_xml_data(lst,root.getroot(), gather_level)
    res.append(lst)

def get_table_names(xml_data_list): 
    table_names = []
    for t in xml_data_list:
        if t[0]:
            if re.match(r'(-{http://webservices.irb.com/}\w)', t[0], re.IGNORECASE):
                name = t[0][30:].strip()
                table_names.append(name)
    return table_names
                
tables = get_table_names(res[0])

for xml_file in xml_files:
    lst = []
    root = et.parse(xml_file)
    compute_xml_data(lst,root.getroot(), gather_level)

# build all the dataframe from the xml, see next script for dataframe reference.
def build_xml_dfs(xmls):
    MatchID_tag = '--{http://webservices.irb.com/}MatchID'
    match_info_tag = '-{http://webservices.irb.com/}MatchInformation'
    officials_tag = '-{http://webservices.irb.com/}Officials'
    official_tag = '--{http://webservices.irb.com/}Official'
    team1TeamSheet_tag = '-{http://webservices.irb.com/}Team1TeamSheet'
    team2TeamSheet_tag = '-{http://webservices.irb.com/}Team2TeamSheet'
    player_tag = '--{http://webservices.irb.com/}Player'
    timeline_tag = '-{http://webservices.irb.com/}Timeline'
    timelineEntry_tag = '--{http://webservices.irb.com/}TimelineEntry'
    
    MatchID_idx = [xml[0] for xml in xmls].index(MatchID_tag)
    MatchID = xmls[MatchID_idx][1]
    
    match_info_list = []
    officials_list = []
    team1TeamSheet_list = []
    team2TeamSheet_list = []
    timeline_list = []
    
    for t in xmls:
        if t[0] == match_info_tag: 
            match_info_start_idx = [xml[0] for xml in xmls].index(match_info_tag)
            officials_start_idx = [xml[0] for xml in xmls].index(officials_tag)
            team1TeamSheet_start_idx = [xml[0] for xml in xmls].index(team1TeamSheet_tag)
            team2TeamSheet_start_idx = [xml[0] for xml in xmls].index(team2TeamSheet_tag)
            timeline_start_idx = [xml[0] for xml in xmls].index(timeline_tag)

            for m in xmls[match_info_start_idx+1:officials_start_idx]:
                if m[0] is not officials_tag:
                    match_info_list.append((m[0][31:].strip(),m[1]))
                else:
                    continue
            for o in xmls[officials_start_idx+1:team1TeamSheet_start_idx]:
                if o[0] == official_tag:
                    sub_list = []
                    sub_list.append(('MatchID',MatchID))
                    officials_list.append(sub_list)
                elif o[0] is not team1TeamSheet_tag:
                    sub_list.append((o[0][32:].strip(),o[1]))
                else:
                    continue
            for t1 in xmls[team1TeamSheet_start_idx+1:team2TeamSheet_start_idx]: #25/132
                if t1[0] == player_tag:
                    sub_list = []
                    sub_list.append(('MatchID',MatchID))
                    team1TeamSheet_list.append(sub_list)
                elif t1[0] is not team2TeamSheet_tag:
                    sub_list.append((t1[0][32:].strip(),t1[1]))
                else:
                    continue
            for t2 in xmls[team2TeamSheet_start_idx+1:timeline_start_idx]:
                if t2[0] == player_tag:
                    sub_list = []
                    sub_list.append(('MatchID',MatchID))
                    team2TeamSheet_list.append(sub_list)
                elif t2[0] is not team2TeamSheet_tag:
                    sub_list.append((t2[0][32:].strip(),t2[1]))
                else:
                    continue
            for time_line in xmls[timeline_start_idx+1:]:
                if time_line[0] == timelineEntry_tag:
                    sub_list = []
                    sub_list.append(('MatchID',MatchID))
                    timeline_list.append(sub_list)
                elif time_line[0]:
                    sub_list.append((time_line[0][32:].strip(),time_line[1]))
                else:
                    break                 

    records_dict = {'match_info': match_info_list, 'officials': officials_list, 'team1TeamSheet': team1TeamSheet_list, 'team2TeamSheet':team2TeamSheet_list,'timeline':timeline_list}
    
    match_info_df = pd.DataFrame.from_records(match_info_list).transpose()
    match_info_df = match_info_df.rename(columns=match_info_df.iloc[0]).drop(match_info_df.index[0])
    
    officials_df = [pd.DataFrame.from_records(lst).transpose() for lst in officials_list]
    officials_df = [df.rename(columns=df.iloc[0]).drop(df.index[0]) for df in officials_df]
    
    team1TeamSheet_df = [pd.DataFrame.from_records(lst).transpose() for lst in team1TeamSheet_list]
    team1TeamSheet_df = [df.rename(columns=df.iloc[0]).drop(df.index[0]) for df in team1TeamSheet_df]
    
    team2TeamSheet_df = [pd.DataFrame.from_records(lst).transpose() for lst in team2TeamSheet_list]
    team2TeamSheet_df = [df.rename(columns=df.iloc[0]).drop(df.index[0]) for df in team2TeamSheet_df]
    
    timeline_df = [pd.DataFrame.from_records(lst).transpose() for lst in timeline_list]
    timeline_df = [df.rename(columns=df.iloc[0]).drop(df.index[0]) for df in timeline_df]
    
    match_info_dfs_merged = match_info_df
    officials_dfs_merged = pd.concat(officials_df)
    team1TeamSheet_dfs_merged = pd.concat(team1TeamSheet_df)
    team2TeamSheet_dfs_merged = pd.concat(team2TeamSheet_df)
    timeline_dfs_merged = pd.concat(timeline_df)
    
    return {'match_info':match_info_dfs_merged,
            'officials':officials_dfs_merged,
            'team1TeamSheet':team1TeamSheet_dfs_merged,
            'team2TeamSheet':team2TeamSheet_dfs_merged,
            'timeline':timeline_dfs_merged}

all_xml_dfs = []
match_info_dfs_list = []
officials_dfs_list = []
team1TeamSheet_dfs_list = []
team2TeamSheet_dfs_list = []
timeline_dfs_list = []

for xml_data in res:
    all_xml_dfs.append(build_xml_dfs(xml_data))

for df_dict in all_xml_dfs:
    for k,v in df_dict.items():
        if k == 'match_info':
            match_info_dfs_list.append(v)
        if k == 'officials':
            officials_dfs_list.append(v)
        if k == 'team1TeamSheet':
            team1TeamSheet_dfs_list.append(v)
        if k == 'team2TeamSheet':
            team2TeamSheet_dfs_list.append(v)
        if k == 'timeline':
            timeline_dfs_list.append(v)

match_info_dfs_merged_all = pd.concat(match_info_dfs_list)
officials_dfs_merged_all = pd.concat(officials_dfs_list)
team1TeamSheet_dfs_merged_all = pd.concat(team1TeamSheet_dfs_list)
team2TeamSheet_dfs_merged_all = pd.concat(team2TeamSheet_dfs_list)
timeline_dfs_merged_all = pd.concat(timeline_dfs_list)

# load dataframe into Postgres
def write_data_to_sql(df, table_name):        
    try:
        engine = sa.create_engine(connection_string, echo=True);
        # add a table id?
        # df["TableId"] = tableId;
        if not df.empty:
            df.to_sql(tablename, engine, if_exists='append', index=False)       
    except Exception as e:
        print(e)

match_info_dfs_merged_all.to_csv('./matchwithtimeline_matchinformation.csv',index=False)
officials_dfs_merged_all.to_csv('./matchwithtimeline_officials.csv',index=False)
team1TeamSheet_dfs_merged_all.to_csv('./matchwithtimeline_team1teamsheet.csv',index=False)
team2TeamSheet_dfs_merged_all.to_csv('./matchwithtimeline_team2teamsheet.csv',index=False)
timeline_dfs_merged_all.to_csv('./matchwithtimeline_timeline.csv',index=False)
print('Completed!')
# Out:
#    MatchID PersonID                 PersonName Position
# 1    22808    26344               Mike Adamson  Referee
# 1    22809    37180  Marius Van Der Westhuizen  Referee
# 1    22810    49879             Alexandre Ruiz  Referee
# 1    22811    21018              Craig Joubert  Referee
# 1    22812    42481               Matt O'Brien  Referee
# 1    22813    42676              Richard Kelly  Referee
# 1    22814    36319           Federico Anselmi  Referee
# 1    22815    42594                Nick Briant  Referee
# 1    22816    42481               Matt O'Brien  Referee
# 1    22817    42676              Richard Kelly  Referee
# 1    22818    42594                Nick Briant  Referee
# 1    22819    37180  Marius Van Der Westhuizen  Referee
# 1    22820    36319           Federico Anselmi  Referee
# 1    22821    21018              Craig Joubert  Referee
# 1    22822    49879             Alexandre Ruiz  Referee
# 1    22823    26344               Mike Adamson  Referee
# 1    22824    36319           Federico Anselmi  Referee
# 1    22825    49879             Alexandre Ruiz  Referee
# 1    22826    42676              Richard Kelly  Referee
# 1    22827    42481               Matt O'Brien  Referee
# 1    22828    42594                Nick Briant  Referee
# 1    22829    26344               Mike Adamson  Referee
# 1    22830    37180  Marius Van Der Westhuizen  Referee
# 1    22831    21018              Craig Joubert  Referee
# 1    22832    49879             Alexandre Ruiz  Referee
# 1    22833    37180  Marius Van Der Westhuizen  Referee
# 1    22834    21018              Craig Joubert  Referee
# 1    22835    36319           Federico Anselmi  Referee
# 1    22836    42676              Richard Kelly  Referee
# 1    22837    42481               Matt O'Brien  Referee
# ..     ...      ...                        ...      ...
# 1    24918    59981            Sam Grove-White  Referee
# 1    24919    59555              James Doleman  Referee
# 1    24920    46436           Rasta Rashivenge  Referee
# 1    24921    46996                 Ben Crouse  Referee
# 1    24922    59554           Richard Haughton  Referee
# 1    24923    42676              Richard Kelly  Referee
# 1    24924    59981            Sam Grove-White  Referee
# 1    24925    59556                Craig Evans  Referee
# 1    24926    21018              Craig Joubert  Referee
# 1    24927    46436           Rasta Rashivenge  Referee
# 1    24928    59555              James Doleman  Referee
# 1    24929    59554           Richard Haughton  Referee
# 1    24930    59559                 Jaco Kotze  Referee
# 1    24931    21018              Craig Joubert  Referee
# 1    24932    59557           Damian Schneider  Referee
# 1    24933    59556                Craig Evans  Referee
# 1    24934    42676              Richard Kelly  Referee
# 1    24935    46996                 Ben Crouse  Referee
# 1    24936    59555              James Doleman  Referee
# 1    24937    59559                 Jaco Kotze  Referee
# 1    24938    59557           Damian Schneider  Referee
# 1    24939    46996                 Ben Crouse  Referee
# 1    24940    59554           Richard Haughton  Referee
# 1    24941    46436           Rasta Rashivenge  Referee
# 1    24942    59981            Sam Grove-White  Referee
# 1    24943    42676              Richard Kelly  Referee
# 1    24944    59555              James Doleman  Referee
# 1    24945    59556                Craig Evans  Referee
# 1    24946    59554           Richard Haughton  Referee
# 1    24947    21018              Craig Joubert  Referee
#
# [900 rows x 4 columns]

# %%
#run below script to find out the xml format, only run if format is due to change.

# %%
import xml.etree.ElementTree as et
import glob
import re
import pandas as pd
from collections import OrderedDict
import sqlalchemy as sa
    
res = []

def compute_xml_data(elem, func, level=0):
    func(elem,level)
    for child in elem.getchildren():
        compute_xml_data(child, func, level+1)

def gather_level(elem,level):
    print('-'*level+elem.tag, elem.text)
#     res.append(('-'*level+elem.tag, elem.text))

xml_files = glob.glob('./*.xml')


xml_data = compute_xml_data(root.getroot(), gather_level)

def get_table_names(xml_data_list): 
    table_names = []
    for t in xml_data_list:
        if t[0]:
            if re.match(r'(-{http://webservices.irb.com/}\w)', t[0], re.IGNORECASE):
                name = t[0][30:].strip()
                table_names.append(name)
    return table_names

# print(res)

print(get_table_names(res))

# compute_xml_data(root.getroot(), gather_level)
# Out:
# {http://webservices.irb.com/}MatchDetailWithTimeline
#
# -{http://webservices.irb.com/}MatchInformation
#
# --{http://webservices.irb.com/}MatchID 24947
# --{http://webservices.irb.com/}KickOff 2017-05-21T17:57:00
# --{http://webservices.irb.com/}GMTDifference 1.0
# --{http://webservices.irb.com/}Team1ID 2419
# --{http://webservices.irb.com/}Team1Name Scotland 7s
# --{http://webservices.irb.com/}Team1Score 12
# --{http://webservices.irb.com/}Team2ID 2412
# --{http://webservices.irb.com/}Team2Name England 7s
# --{http://webservices.irb.com/}Team2Score 7
# --{http://webservices.irb.com/}Stadium Twickenham
# --{http://webservices.irb.com/}City London
# --{http://webservices.irb.com/}Attendance None
# --{http://webservices.irb.com/}Stage None
# --{http://webservices.irb.com/}Group None
# --{http://webservices.irb.com/}Status Match Completed
# --{http://webservices.irb.com/}MatchNumber None
# -{http://webservices.irb.com/}Officials
#
# --{http://webservices.irb.com/}Official
#
# ---{http://webservices.irb.com/}PersonID 21018
# ---{http://webservices.irb.com/}PersonName Craig Joubert
# ---{http://webservices.irb.com/}Position Referee
# -{http://webservices.irb.com/}Team1TeamSheet
#
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 51788
# ---{http://webservices.irb.com/}PersonName Scott Riddell
# ---{http://webservices.irb.com/}IsCaptain true
# ---{http://webservices.irb.com/}Position Forward
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 38829
# ---{http://webservices.irb.com/}PersonName Dougie Fife
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Back
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 55784
# ---{http://webservices.irb.com/}PersonName Hugh Blake
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Forward
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 60228
# ---{http://webservices.irb.com/}PersonName Grayson Jon Hart
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 55785
# ---{http://webservices.irb.com/}PersonName Glenn Bryce
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute true
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 38138
# ---{http://webservices.irb.com/}PersonName Mark Robertson
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Forward
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 55783
# ---{http://webservices.irb.com/}PersonName Jamie Farndale
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute true
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 51780
# ---{http://webservices.irb.com/}PersonName Joseva Nayacavou
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute true
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 55641
# ---{http://webservices.irb.com/}PersonName George Horne
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Back
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 26802
# ---{http://webservices.irb.com/}PersonName Scott Wight
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Back
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 51742
# ---{http://webservices.irb.com/}PersonName James Fleming
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Back
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 28901
# ---{http://webservices.irb.com/}PersonName Jack Cuthbert
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# -{http://webservices.irb.com/}Team2TeamSheet
#
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 44109
# ---{http://webservices.irb.com/}PersonName Richard de Carpentier
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute true
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 47437
# ---{http://webservices.irb.com/}PersonName Charlie Hayter
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Forward
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 47432
# ---{http://webservices.irb.com/}PersonName Phil Burgess
# ---{http://webservices.irb.com/}IsCaptain true
# ---{http://webservices.irb.com/}Position Forward
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 51662
# ---{http://webservices.irb.com/}PersonName Dan Norton
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Back
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 51671
# ---{http://webservices.irb.com/}PersonName James Rodwell
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Forward
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 59373
# ---{http://webservices.irb.com/}PersonName William Edwards
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Back
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 59378
# ---{http://webservices.irb.com/}PersonName Callum Sirker
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 51654
# ---{http://webservices.irb.com/}PersonName Oliver Lindsay-Hague
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Back
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 56571
# ---{http://webservices.irb.com/}PersonName Ruaridh McConnochie
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Back
# ---{http://webservices.irb.com/}IsSubstitute false
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 56569
# ---{http://webservices.irb.com/}PersonName Harry Glover
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute true
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 58720
# ---{http://webservices.irb.com/}PersonName Alex Davis
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute true
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# --{http://webservices.irb.com/}Player
#
# ---{http://webservices.irb.com/}PersonID 59375
# ---{http://webservices.irb.com/}PersonName William Glover
# ---{http://webservices.irb.com/}IsCaptain false
# ---{http://webservices.irb.com/}Position Replacement
# ---{http://webservices.irb.com/}IsSubstitute true
# ---{http://webservices.irb.com/}IsUsedSubstitute false
# ---{http://webservices.irb.com/}TeamsRepresenting None
# ---{http://webservices.irb.com/}IsPlayerOfMatch false
# -{http://webservices.irb.com/}Timeline
#
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399117
# ---{http://webservices.irb.com/}IsTeam1 None
# ---{http://webservices.irb.com/}PersonId None
# ---{http://webservices.irb.com/}PersonName None
# ---{http://webservices.irb.com/}ActionTypeId 104
# ---{http://webservices.irb.com/}ActionTypeName Change Match Status
# ---{http://webservices.irb.com/}ActionTypeGroup Clock
# ---{http://webservices.irb.com/}ActionTypeSubGroup MS
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 0
# ---{http://webservices.irb.com/}MatchStatusId 5
# ---{http://webservices.irb.com/}MatchStatusName First Half
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T16:56:37
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T17:56:35
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399118
# ---{http://webservices.irb.com/}IsTeam1 false
# ---{http://webservices.irb.com/}PersonId 44109
# ---{http://webservices.irb.com/}PersonName Richard de Carpentier
# ---{http://webservices.irb.com/}ActionTypeId 85
# ---{http://webservices.irb.com/}ActionTypeName Replacement On
# ---{http://webservices.irb.com/}ActionTypeGroup Replacement
# ---{http://webservices.irb.com/}ActionTypeSubGroup Sub On
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 176
# ---{http://webservices.irb.com/}MatchStatusId 5
# ---{http://webservices.irb.com/}MatchStatusName First Half
# ---{http://webservices.irb.com/}ActionLink 5933ed78-98f5-41ec-9be9-d5f05bd799d6
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T16:59:32
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T17:59:31
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399119
# ---{http://webservices.irb.com/}IsTeam1 false
# ---{http://webservices.irb.com/}PersonId 51662
# ---{http://webservices.irb.com/}PersonName Dan Norton
# ---{http://webservices.irb.com/}ActionTypeId 2
# ---{http://webservices.irb.com/}ActionTypeName Try
# ---{http://webservices.irb.com/}ActionTypeGroup Score
# ---{http://webservices.irb.com/}ActionTypeSubGroup Try
# ---{http://webservices.irb.com/}ActionTypeValue 5
# ---{http://webservices.irb.com/}Time 427
# ---{http://webservices.irb.com/}MatchStatusId 5
# ---{http://webservices.irb.com/}MatchStatusName First Half
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:03:43
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:03:42
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399120
# ---{http://webservices.irb.com/}IsTeam1 false
# ---{http://webservices.irb.com/}PersonId 59373
# ---{http://webservices.irb.com/}PersonName William Edwards
# ---{http://webservices.irb.com/}ActionTypeId 4
# ---{http://webservices.irb.com/}ActionTypeName Conversion
# ---{http://webservices.irb.com/}ActionTypeGroup Score
# ---{http://webservices.irb.com/}ActionTypeSubGroup Con
# ---{http://webservices.irb.com/}ActionTypeValue 2
# ---{http://webservices.irb.com/}Time 469
# ---{http://webservices.irb.com/}MatchStatusId 5
# ---{http://webservices.irb.com/}MatchStatusName First Half
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:04:26
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:04:24
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399121
# ---{http://webservices.irb.com/}IsTeam1 false
# ---{http://webservices.irb.com/}PersonId 58720
# ---{http://webservices.irb.com/}PersonName Alex Davis
# ---{http://webservices.irb.com/}ActionTypeId 85
# ---{http://webservices.irb.com/}ActionTypeName Replacement On
# ---{http://webservices.irb.com/}ActionTypeGroup Replacement
# ---{http://webservices.irb.com/}ActionTypeSubGroup Sub On
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 724
# ---{http://webservices.irb.com/}MatchStatusId 5
# ---{http://webservices.irb.com/}MatchStatusName First Half
# ---{http://webservices.irb.com/}ActionLink cb0d8413-c0eb-44bb-9d8f-e868bc69271d
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:08:40
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:08:39
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399122
# ---{http://webservices.irb.com/}IsTeam1 None
# ---{http://webservices.irb.com/}PersonId None
# ---{http://webservices.irb.com/}PersonName None
# ---{http://webservices.irb.com/}ActionTypeId 104
# ---{http://webservices.irb.com/}ActionTypeName Change Match Status
# ---{http://webservices.irb.com/}ActionTypeGroup Clock
# ---{http://webservices.irb.com/}ActionTypeSubGroup MS
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 949
# ---{http://webservices.irb.com/}MatchStatusId 6
# ---{http://webservices.irb.com/}MatchStatusName Half Time
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:12:25
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:12:24
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399123
# ---{http://webservices.irb.com/}IsTeam1 None
# ---{http://webservices.irb.com/}PersonId None
# ---{http://webservices.irb.com/}PersonName None
# ---{http://webservices.irb.com/}ActionTypeId 104
# ---{http://webservices.irb.com/}ActionTypeName Change Match Status
# ---{http://webservices.irb.com/}ActionTypeGroup Clock
# ---{http://webservices.irb.com/}ActionTypeSubGroup MS
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 0
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:15:14
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:15:13
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399124
# ---{http://webservices.irb.com/}IsTeam1 false
# ---{http://webservices.irb.com/}PersonId 47437
# ---{http://webservices.irb.com/}PersonName Charlie Hayter
# ---{http://webservices.irb.com/}ActionTypeId 85
# ---{http://webservices.irb.com/}ActionTypeName Replacement On
# ---{http://webservices.irb.com/}ActionTypeGroup Replacement
# ---{http://webservices.irb.com/}ActionTypeSubGroup Sub On
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 6
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink 335ff4b3-6713-4ef9-b582-7015479b3c46
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:15:20
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:15:19
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399125
# ---{http://webservices.irb.com/}IsTeam1 true
# ---{http://webservices.irb.com/}PersonId 55784
# ---{http://webservices.irb.com/}PersonName Hugh Blake
# ---{http://webservices.irb.com/}ActionTypeId 2
# ---{http://webservices.irb.com/}ActionTypeName Try
# ---{http://webservices.irb.com/}ActionTypeGroup Score
# ---{http://webservices.irb.com/}ActionTypeSubGroup Try
# ---{http://webservices.irb.com/}ActionTypeValue 5
# ---{http://webservices.irb.com/}Time 45
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:15:59
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:15:58
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399126
# ---{http://webservices.irb.com/}IsTeam1 true
# ---{http://webservices.irb.com/}PersonId 26802
# ---{http://webservices.irb.com/}PersonName Scott Wight
# ---{http://webservices.irb.com/}ActionTypeId 4
# ---{http://webservices.irb.com/}ActionTypeName Conversion
# ---{http://webservices.irb.com/}ActionTypeGroup Score
# ---{http://webservices.irb.com/}ActionTypeSubGroup Con
# ---{http://webservices.irb.com/}ActionTypeValue 2
# ---{http://webservices.irb.com/}Time 70
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:16:26
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:16:23
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399127
# ---{http://webservices.irb.com/}IsTeam1 true
# ---{http://webservices.irb.com/}PersonId 55785
# ---{http://webservices.irb.com/}PersonName Glenn Bryce
# ---{http://webservices.irb.com/}ActionTypeId 85
# ---{http://webservices.irb.com/}ActionTypeName Replacement On
# ---{http://webservices.irb.com/}ActionTypeGroup Replacement
# ---{http://webservices.irb.com/}ActionTypeSubGroup Sub On
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 190
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink a15d703e-3974-4557-b1a4-7d528cda1344
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:18:25
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:18:23
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399128
# ---{http://webservices.irb.com/}IsTeam1 true
# ---{http://webservices.irb.com/}PersonId 55783
# ---{http://webservices.irb.com/}PersonName Jamie Farndale
# ---{http://webservices.irb.com/}ActionTypeId 85
# ---{http://webservices.irb.com/}ActionTypeName Replacement On
# ---{http://webservices.irb.com/}ActionTypeGroup Replacement
# ---{http://webservices.irb.com/}ActionTypeSubGroup Sub On
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 193
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink 4668726b-828f-4f75-b88c-1738f097e234
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:18:27
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:18:26
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399129
# ---{http://webservices.irb.com/}IsTeam1 true
# ---{http://webservices.irb.com/}PersonId 51780
# ---{http://webservices.irb.com/}PersonName Joseva Nayacavou
# ---{http://webservices.irb.com/}ActionTypeId 85
# ---{http://webservices.irb.com/}ActionTypeName Replacement On
# ---{http://webservices.irb.com/}ActionTypeGroup Replacement
# ---{http://webservices.irb.com/}ActionTypeSubGroup Sub On
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 195
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink 728b6c59-3c10-4f49-8e56-95b7858de2ae
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:18:29
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:18:28
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399130
# ---{http://webservices.irb.com/}IsTeam1 true
# ---{http://webservices.irb.com/}PersonId 51788
# ---{http://webservices.irb.com/}PersonName Scott Riddell
# ---{http://webservices.irb.com/}ActionTypeId 2
# ---{http://webservices.irb.com/}ActionTypeName Try
# ---{http://webservices.irb.com/}ActionTypeGroup Score
# ---{http://webservices.irb.com/}ActionTypeSubGroup Try
# ---{http://webservices.irb.com/}ActionTypeValue 5
# ---{http://webservices.irb.com/}Time 282
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:19:56
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:19:55
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399131
# ---{http://webservices.irb.com/}IsTeam1 true
# ---{http://webservices.irb.com/}PersonId 26802
# ---{http://webservices.irb.com/}PersonName Scott Wight
# ---{http://webservices.irb.com/}ActionTypeId 30
# ---{http://webservices.irb.com/}ActionTypeName Missed Conversion
# ---{http://webservices.irb.com/}ActionTypeGroup Score
# ---{http://webservices.irb.com/}ActionTypeSubGroup M Con
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 326
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:20:42
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:20:39
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399132
# ---{http://webservices.irb.com/}IsTeam1 false
# ---{http://webservices.irb.com/}PersonId 56569
# ---{http://webservices.irb.com/}PersonName Harry Glover
# ---{http://webservices.irb.com/}ActionTypeId 85
# ---{http://webservices.irb.com/}ActionTypeName Replacement On
# ---{http://webservices.irb.com/}ActionTypeGroup Replacement
# ---{http://webservices.irb.com/}ActionTypeSubGroup Sub On
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 333
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink 2d86fc40-78c2-44b7-8db0-f69374af741d
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:20:47
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:20:46
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399133
# ---{http://webservices.irb.com/}IsTeam1 false
# ---{http://webservices.irb.com/}PersonId 51671
# ---{http://webservices.irb.com/}PersonName James Rodwell
# ---{http://webservices.irb.com/}ActionTypeId 85
# ---{http://webservices.irb.com/}ActionTypeName Replacement On
# ---{http://webservices.irb.com/}ActionTypeGroup Replacement
# ---{http://webservices.irb.com/}ActionTypeSubGroup Sub On
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 435
# ---{http://webservices.irb.com/}MatchStatusId 7
# ---{http://webservices.irb.com/}MatchStatusName Second Half
# ---{http://webservices.irb.com/}ActionLink 71581962-9ef2-4927-bcfe-76a9bfd4907f
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:22:29
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:22:28
# --{http://webservices.irb.com/}TimelineEntry
#
# ---{http://webservices.irb.com/}TimelineId 399134
# ---{http://webservices.irb.com/}IsTeam1 None
# ---{http://webservices.irb.com/}PersonId None
# ---{http://webservices.irb.com/}PersonName None
# ---{http://webservices.irb.com/}ActionTypeId 104
# ---{http://webservices.irb.com/}ActionTypeName Change Match Status
# ---{http://webservices.irb.com/}ActionTypeGroup Clock
# ---{http://webservices.irb.com/}ActionTypeSubGroup MS
# ---{http://webservices.irb.com/}ActionTypeValue 0
# ---{http://webservices.irb.com/}Time 475
# ---{http://webservices.irb.com/}MatchStatusId 8
# ---{http://webservices.irb.com/}MatchStatusName Full Time
# ---{http://webservices.irb.com/}ActionLink None
# ---{http://webservices.irb.com/}Timestamp 2017-05-21T17:23:10
# ---{http://webservices.irb.com/}ThirdPartyTimestamp 2017-05-21T18:23:08
# []
